# %% [markdown]
# # Exportation des DataFrames pour intégration Sqlit # P3_Réalisez une étude de santé publique

# %%
#impotter des librairies
import pandas as pd
import numpy as np
#impotter de librairie sqlite3 et Créer une base de données

# %%
import csv ,sqlite3
#Faire la base de données 
con = sqlite3.connect('sécurité_alimentaire.db ')
cur =con.cursor()

# %% [markdown]
# # Question 15 : Proposez une clé primaire pertinente pour cette table.¶
# Votre base devra contenir ces différentes tables : Une table appelée population, contenant la population de chaque pays pour 2013. Elle devra contenir 4 colonnes : pays, code_pays, annee, population.

# %% [markdown]
# ##### Réponse à la question 15 : Tableau « Population »\ J'ai choisi la propriété "code pays" comme clé primaire car elle est unique et courte et ne peut pas être nulle

# %%
#Créer une table à l'aide de sqlite
cur.execute("""CREATE TABLE 'population' (
"pays" TEXT NOT NULL,
 "code_pays" INTEGER NOT NULL,
 "annee" INTEGER NOT NULL,
 "population" INTEGER NOT NULL,
 PRIMARY KEY("code_pays")
)""");

# %%
#importer un fichier CSV
df_population = pd.read_csv('population.csv')
#Exporter la table en tant que SQL dans une base de données
df_population.to_sql('population', con, if_exists='append', index=False)

# %%
#Requête de table
cur.execute ("select * from 'population'")
cur.fetchall()
# Out:
# [('Arménie', 1, 2013, 2977000),
#  ('Afghanistan', 2, 2013, 30552000),
#  ('Albanie', 3, 2013, 3173000),
#  ('Algérie', 4, 2013, 39208000),
#  ('Angola', 7, 2013, 21472000),
#  ('Antigua-et-Barbuda', 8, 2013, 90000),
#  ('Argentine', 9, 2013, 41446000),
#  ('Australie', 10, 2013, 23343000),
#  ('Autriche', 11, 2013, 8495000),
#  ('Bahamas', 12, 2013, 377000),
#  ('Barbade', 14, 2013, 285000),
#  ('Bangladesh', 16, 2013, 156595000),
#  ('Bermudes', 17, 2013, 65000),
#  ('Bolivie (État plurinational de)', 19, 2013, 10671000),
#  ('Botswana', 20, 2013, 2021000),
#  ('Brésil', 21, 2013, 200362000),
#  ('Belize', 23, 2013, 332000),
#  ('Îles Salomon', 25, 2013, 561000),
#  ('Brunéi Darussalam', 26, 2013, 418000),
#  ('Bulgarie', 27, 2013, 7223000),
#  ('Myanmar', 28, 2013, 53259000),
#  ('Cameroun', 32, 2013, 22254000),
#  ('Canada', 33, 2013, 35182000),
#  ('Cabo Verde', 35, 2013, 499000),
#  ('République centrafricaine', 37, 2013, 4616000),
#  ('Sri Lanka', 38, 2013, 21273000),
#  ('Tchad', 39, 2013, 12825000),
#  ('Chili', 40, 2013, 17620000),
#  ('Chine, continentale', 41, 2013, 1385567000),
#  ('Colombie', 44, 2013, 48321000),
#  ('Congo', 46, 2013, 4448000),
#  ('Costa Rica', 48, 2013, 4872000),
#  ('Cuba', 49, 2013, 11266000),
#  ('Chypre', 50, 2013, 1141000),
#  ('Azerbaïdjan', 52, 2013, 9413000),
#  ('Bénin', 53, 2013, 10323000),
#  ('Danemark', 54, 2013, 5619000),
#  ('Dominique', 55, 2013, 72000),
#  ('République dominicaine', 56, 2013, 10404000),
#  ('Bélarus', 57, 2013, 9357000),
#  ('Équateur', 58, 2013, 15738000),
#  ('Égypte', 59, 2013, 82056000),
#  ('El Salvador', 60, 2013, 6340000),
#  ('Estonie', 63, 2013, 1287000),
#  ('Fidji', 66, 2013, 881000),
#  ('Finlande', 67, 2013, 5426000),
#  ('France', 68, 2013, 64291000),
#  ('Polynésie française', 70, 2013, 277000),
#  ('Djibouti', 72, 2013, 873000),
#  ('Géorgie', 73, 2013, 4341000),
#  ('Gabon', 74, 2013, 1672000),
#  ('Gambie', 75, 2013, 1849000),
#  ('Allemagne', 79, 2013, 82727000),
#  ('Bosnie-Herzégovine', 80, 2013, 3829000),
#  ('Ghana', 81, 2013, 25905000),
#  ('Kiribati', 83, 2013, 102000),
#  ('Grèce', 84, 2013, 11128000),
#  ('Grenade', 86, 2013, 106000),
#  ('Guatemala', 89, 2013, 15468000),
#  ('Guinée', 90, 2013, 11745000),
#  ('Guyana', 91, 2013, 800000),
#  ('Haïti', 93, 2013, 10317000),
#  ('Honduras', 95, 2013, 8096000),
#  ('Chine - RAS de Hong-Kong', 96, 2013, 7204000),
#  ('Hongrie', 97, 2013, 9955000),
#  ('Croatie', 98, 2013, 4290000),
#  ('Islande', 99, 2013, 330000),
#  ('Inde', 100, 2013, 1252140000),
#  ('Indonésie', 101, 2013, 249866000),
#  ("Iran (République islamique d')", 102, 2013, 77447000),
#  ('Iraq', 103, 2013, 33765000),
#  ('Irlande', 104, 2013, 4627000),
#  ('Israël', 105, 2013, 7733000),
#  ('Italie', 106, 2013, 60990000),
#  ("Côte d'Ivoire", 107, 2013, 20316000),
#  ('Kazakhstan', 108, 2013, 16441000),
#  ('Jamaïque', 109, 2013, 2784000),
#  ('Japon', 110, 2013, 127144000),
#  ('Jordanie', 112, 2013, 7274000),
#  ('Kirghizistan', 113, 2013, 5548000),
#  ('Kenya', 114, 2013, 44354000),
#  ('Cambodge', 115, 2013, 15135000),
#  ('République populaire démocratique de Corée', 116, 2013, 24895000),
#  ('République de Corée', 117, 2013, 49263000),
#  ('Koweït', 118, 2013, 3369000),
#  ('Lettonie', 119, 2013, 2050000),
#  ('République démocratique populaire lao', 120, 2013, 6770000),
#  ('Liban', 121, 2013, 4822000),
#  ('Lesotho', 122, 2013, 2074000),
#  ('Libéria', 123, 2013, 4294000),
#  ('Lituanie', 126, 2013, 3017000),
#  ('Chine - RAS de Macao', 128, 2013, 566000),
#  ('Madagascar', 129, 2013, 22925000),
#  ('Malawi', 130, 2013, 16363000),
#  ('Malaisie', 131, 2013, 29717000),
#  ('Maldives', 132, 2013, 345000),
#  ('Mali', 133, 2013, 15302000),
#  ('Malte', 134, 2013, 429000),
#  ('Mauritanie', 136, 2013, 3890000),
#  ('Maurice', 137, 2013, 1244000),
#  ('Mexique', 138, 2013, 122332000),
#  ('Mongolie', 141, 2013, 2839000),
#  ('Maroc', 143, 2013, 33008000),
#  ('Mozambique', 144, 2013, 25834000),
#  ('République de Moldova', 146, 2013, 3487000),
#  ('Namibie', 147, 2013, 2303000),
#  ('Népal', 149, 2013, 27797000),
#  ('Pays-Bas', 150, 2013, 16759000),
#  ('Nouvelle-Calédonie', 153, 2013, 256000),
#  ('Macédoine du Nord', 154, 2013, 2107000),
#  ('Vanuatu', 155, 2013, 253000),
#  ('Nouvelle-Zélande', 156, 2013, 4506000),
#  ('Nicaragua', 157, 2013, 6080000),
#  ('Niger', 158, 2013, 17831000),
#  ('Nigéria', 159, 2013, 173615000),
#  ('Norvège', 162, 2013, 5043000),
#  ('Pakistan', 165, 2013, 182143000),
#  ('Panama', 166, 2013, 3864000),
#  ('Tchéquie (la)', 167, 2013, 10702000),
#  ('Paraguay', 169, 2013, 6802000),
#  ('Pérou', 170, 2013, 30376000),
#  ('Philippines', 171, 2013, 98394000),
#  ('Pologne', 173, 2013, 38217000),
#  ('Portugal', 174, 2013, 10608000),
#  ('Guinée-Bissau', 175, 2013, 1704000),
#  ('Timor-Leste', 176, 2013, 1133000),
#  ('Zimbabwe', 181, 2013, 14150000),
#  ('Roumanie', 183, 2013, 21699000),
#  ('Rwanda', 184, 2013, 11777000),
#  ('Fédération de Russie', 185, 2013, 142834000),
#  ('Saint-Kitts-et-Nevis', 188, 2013, 54000),
#  ('Sainte-Lucie', 189, 2013, 182000),
#  ('Saint-Vincent-et-les Grenadines', 191, 2013, 109000),
#  ('Sao Tomé-et-Principe', 193, 2013, 193000),
#  ('Arabie saoudite', 194, 2013, 28829000),
#  ('Sénégal', 195, 2013, 14133000),
#  ('Sierra Leone', 197, 2013, 6092000),
#  ('Slovénie', 198, 2013, 2072000),
#  ('Slovaquie', 199, 2013, 5450000),
#  ('Afrique du Sud', 202, 2013, 52776000),
#  ('Espagne', 203, 2013, 46927000),
#  ('Suriname', 207, 2013, 539000),
#  ('Tadjikistan', 208, 2013, 8208000),
#  ('Eswatini', 209, 2013, 1250000),
#  ('Suède', 210, 2013, 9571000),
#  ('Suisse', 211, 2013, 8078000),
#  ('Turkménistan', 213, 2013, 5240000),
#  ('Chine, Taiwan Province de', 214, 2013, 23330000),
#  ('République-Unie de Tanzanie', 215, 2013, 49253000),
#  ('Thaïlande', 216, 2013, 67011000),
#  ('Togo', 217, 2013, 6817000),
#  ('Trinité-et-Tobago', 220, 2013, 1341000),
#  ('Oman', 221, 2013, 3632000),
#  ('Tunisie', 222, 2013, 10997000),
#  ('Turquie', 223, 2013, 74933000),
#  ('Émirats arabes unis', 225, 2013, 9346000),
#  ('Ouganda', 226, 2013, 37579000),
#  ('Royaume-Uni', 229, 2013, 63384000),
#  ('Ukraine', 230, 2013, 45239000),
#  ("États-Unis d'Amérique", 231, 2013, 320051000),
#  ('Burkina Faso', 233, 2013, 16935000),
#  ('Uruguay', 234, 2013, 3407000),
#  ('Ouzbékistan', 235, 2013, 28934000),
#  ('Venezuela (République bolivarienne du)', 236, 2013, 30405000),
#  ('Viet Nam', 237, 2013, 91680000),
#  ('Éthiopie', 238, 2013, 94101000),
#  ('Samoa', 244, 2013, 190000),
#  ('Yémen', 249, 2013, 24407000),
#  ('Zambie', 251, 2013, 14539000),
#  ('Belgique', 255, 2013, 11104000),
#  ('Luxembourg', 256, 2013, 530000),
#  ('Serbie', 272, 2013, 9511000),
#  ('Monténégro', 273, 2013, 621000),
#  ('Soudan', 276, 2013, 37964000)]

# %% [markdown]
# # Question 16 : Proposez une clé primaire pertinente pour cette table.
# Une table appelée dispo_alim contenant pour chaque pays et pour chaque produit en 2013, les informations suivantes:\
# la nature du produit (deux valeurs possibles : “animal” ou “végétal”)\
# disponibilité alimentaire en tonnes\
# disponibilité alimentaire en Kcal/personne/jour\
# disponibilité alimentaire de protéines en g/personne/jour\
# disponibilité alimentaire de matières grasses en g/personne/jour\
# Elle devra contenir ces colonnes : pays, code_pays, année, produit, code_produit, origin, dispo_alim_tonnes, \dispo_alim_kcal_p_j, dispo_prot, dispo_mat_gr .

# %% [markdown]
# ##### Réponse à la question 16. Le "code pays" ne peut pas être considéré comme la clé primaire, car il y a autant d'entrées pour un même pays que le nombre de produits.  De plus, le "code produit" ne peut pas être considéré comme une clé primaire car il y aura autant d'entrées pour un même produit que le nombre de pays. Nous allons donc considérer la clé primaire qui se compose de deux colonnes,"code pays" et "code produit"

# %%
#Créer une table à l'aide de sqlite
cur.execute("""CREATE TABLE 'dispo_alim' (
 "code_pays" INTEGER NOT NULL,
 "pays" TEXT,
 "année" INTEGER NOT NULL,
 "code_produit" INTEGER NOT NULL,
 "produit" TEXT,
 "origin" TEXT,
 "dispo_alim_kcal_p_j" REAL,
 "dispo_prot" REAL,
 "dispo_mat_gr" REAL,
 "dispo_alim_tonnes" REAL,
 PRIMARY KEY("code_pays","code_produit")
)""");

# %%
#importer un fichier CSV
df_dispo_alim = pd.read_csv('dispo_alim.csv')
#Exporter la table en tant que SQL dans une base de données
df_dispo_alim.to_sql('dispo_alim', con, if_exists='append', index=False)

# %%
#Requête de table
cur.execute ("select * from 'dispo_alim'")
cur.fetchall()
# Out:
# [(1, 'Arménie', 2013, 2511, 'Blé', 'vegetal', 1024.0, 30.52, 3.6, 141910613.0),
#  (1, 'Arménie', 2013, 2513, 'Orge', 'vegetal', 0.0, 0.0, 0.0, 0.0),
#  (1, 'Arménie', 2013, 2514, 'Maïs', 'vegetal', 0.0, 0.01, None, 32598.15),
#  (1, 'Arménie', 2013, 2515, 'Seigle', 'vegetal', 1.0, 0.02, 0.0, 130392.6),
#  (1, 'Arménie', 2013, 2516, 'Avoine', 'vegetal', 2.0, 0.09, 0.03, 402043.85),
#  (1,
#   'Arménie',
#   2013,
#   2520,
#   'Céréales, Autres',
#   'vegetal',
#   14.0,
#   0.39,
#   0.04,
#   2129745.8),
#  (1,
#   'Arménie',
#   2013,
#   2531,
#   'Pommes de Terre',
#   'vegetal',
#   82.0,
#   1.94,
#   0.12,
#   49005885.5),
#  (1,
#   'Arménie',
#   2013,
#   2542,
#   'Sucre Eq Brut',
#   'vegetal',
#   302.0,
#   None,
#   None,
#   35890563.15),
#  (1,
#   'Arménie',
#   2013,
#   2543,
#   'Edulcorants Autres',
#   'vegetal',
#   18.0,
#   None,
#   None,
#   1977621.1),
#  (1,
#   'Arménie',
#   2013,
#   2549,
#   'Légumineuses Autres',
#   'vegetal',
#   0.0,
#   0.0,
#   None,
#   0.0),
#  (1, 'Arménie', 2013, 2551, 'Noix', 'vegetal', 18.0, 0.42, 1.76, 2336200.75),
#  (1, 'Arménie', 2013, 2555, 'Soja', 'vegetal', 0.0, None, None, 0.0),
#  (1,
#   'Arménie',
#   2013,
#   2556,
#   'Arachides Decortiquees',
#   'vegetal',
#   6.0,
#   0.29,
#   0.55,
#   434642.0),
#  (1,
#   'Arménie',
#   2013,
#   2558,
#   'Graines Colza/Moutarde',
#   'vegetal',
#   0.0,
#   0.0,
#   0.0,
#   0.0),
#  (1,
#   'Arménie',
#   2013,
#   2560,
#   'Coco (Incl Coprah)',
#   'vegetal',
#   0.0,
#   0.0,
#   0.03,
#   86928.4),
#  (1, 'Arménie', 2013, 2561, 'Sésame', 'vegetal', 0.0, 0.0, 0.01, 10866.05),
#  (1, 'Arménie', 2013, 2563, 'Olives', 'vegetal', 3.0, 0.03, 0.28, 999676.6),
#  (1,
#   'Arménie',
#   2013,
#   2570,
#   'Plantes Oleiferes, Autre',
#   'vegetal',
#   0.0,
#   None,
#   None,
#   0.0),
#  (1,
#   'Arménie',
#   2013,
#   2571,
#   'Huile de Soja',
#   'vegetal',
#   4.0,
#   None,
#   0.5,
#   195588.9),
#  (1,
#   'Arménie',
#   2013,
#   2572,
#   "Huile d'Arachide",
#   'vegetal',
#   0.0,
#   None,
#   0.0,
#   0.0),
#  (1,
#   'Arménie',
#   2013,
#   2573,
#   'Huile de Tournesol',
#   'vegetal',
#   216.0,
#   0.04,
#   24.38,
#   9616454.25),
#  (1,
#   'Arménie',
#   2013,
#   2574,
#   'Huile de Colza&Moutarde',
#   'vegetal',
#   0.0,
#   None,
#   0.0,
#   0.0),
#  (1,
#   'Arménie',
#   2013,
#   2575,
#   'Huile Graines de Coton',
#   'vegetal',
#   0.0,
#   None,
#   0.0,
#   0.0),
#  (1,
#   'Arménie',
#   2013,
#   2576,
#   'Huile de Palmistes',
#   'vegetal',
#   0.0,
#   None,
#   0.02,
#   10866.05),
#  (1,
#   'Arménie',
#   2013,
#   2578,
#   'Huile de Coco',
#   'vegetal',
#   7.0,
#   None,
#   0.81,
#   325981.5),
#  (1, 'Arménie', 2013, 2579, 'Huile de Sésame', 'vegetal', 0.0, None, 0.0, 0.0),
#  (1,
#   'Arménie',
#   2013,
#   2580,
#   "Huile d'Olive",
#   'vegetal',
#   1.0,
#   None,
#   0.09,
#   32598.15),
#  (1,
#   'Arménie',
#   2013,
#   2582,
#   'Huile de Germe de Maïs',
#   'vegetal',
#   3.0,
#   None,
#   0.39,
#   152124.70000000004),
#  (1,
#   'Arménie',
#   2013,
#   2586,
#   'Huil Plantes Oleif Autr',
#   'vegetal',
#   0.0,
#   0.0,
#   0.02,
#   10866.05),
#  (1,
#   'Arménie',
#   2013,
#   2601,
#   'Tomates',
#   'vegetal',
#   41.0,
#   1.94,
#   0.48,
#   95729900.5),
#  (1,
#   'Arménie',
#   2013,
#   2602,
#   'Oignons',
#   'vegetal',
#   15.0,
#   0.53,
#   0.1,
#   19091649.85),
#  (1,
#   'Arménie',
#   2013,
#   2605,
#   'Légumes, Autres',
#   'vegetal',
#   143.0,
#   6.66,
#   1.18,
#   264284068.1),
#  (1,
#   'Arménie',
#   2013,
#   2611,
#   'Oranges, Mandarines',
#   'vegetal',
#   4.0,
#   0.07,
#   0.01,
#   5193971.9),
#  (1,
#   'Arménie',
#   2013,
#   2612,
#   'Citrons & Limes',
#   'vegetal',
#   0.0,
#   0.01,
#   0.0,
#   336847.55),
#  (1,
#   'Arménie',
#   2013,
#   2613,
#   'Pamplemousse',
#   'vegetal',
#   0.0,
#   0.0,
#   0.0,
#   565034.6),
#  (1,
#   'Arménie',
#   2013,
#   2614,
#   'Agrumes, Autres',
#   'vegetal',
#   0.0,
#   0.01,
#   0.0,
#   499838.3),
#  (1, 'Arménie', 2013, 2615, 'Bananes', 'vegetal', 1.0, 0.01, 0.01, 836685.85),
#  (1,
#   'Arménie',
#   2013,
#   2616,
#   'Bananes plantains',
#   'vegetal',
#   5.0,
#   0.06,
#   0.02,
#   2770842.7499999995),
#  (1, 'Arménie', 2013, 2617, 'Pommes', 'vegetal', 33.0, 0.08, 0.2, 26936937.95),
#  (1, 'Arménie', 2013, 2618, 'Ananas', 'vegetal', 0.0, 0.0, None, 173856.8),
#  (1, 'Arménie', 2013, 2619, 'Dattes', 'vegetal', 1.0, 0.01, 0.0, 162990.75),
#  (1, 'Arménie', 2013, 2620, 'Raisin', 'vegetal', 20.0, 0.19, 0.13, 14712631.7),
#  (1,
#   'Arménie',
#   2013,
#   2625,
#   'Fruits, Autres',
#   'vegetal',
#   76.0,
#   1.41,
#   0.64,
#   68282258.2),
#  (1, 'Arménie', 2013, 2630, 'Café', 'vegetal', 5.0, 0.65, None, 4444214.45),
#  (1,
#   'Arménie',
#   2013,
#   2633,
#   'Feve de Cacao',
#   'vegetal',
#   37.0,
#   0.45,
#   3.42,
#   2488325.45),
#  (1, 'Arménie', 2013, 2635, 'Thé', 'vegetal', 0.0, 0.03, None, 130392.6),
#  (1, 'Arménie', 2013, 2640, 'Poivre', 'vegetal', 0.0, 0.01, 0.0, 32598.15),
#  (1, 'Arménie', 2013, 2641, 'Piments', 'vegetal', 0.0, 0.01, 0.01, 21732.1),
#  (1,
#   'Arménie',
#   2013,
#   2645,
#   'Épices, Autres',
#   'vegetal',
#   0.0,
#   0.01,
#   0.01,
#   21732.1),
#  (1, 'Arménie', 2013, 2655, 'Vin', 'vegetal', 3.0, None, None, 1608175.4),
#  (1, 'Arménie', 2013, 2656, 'Bière', 'vegetal', 9.0, 0.09, None, 7019468.3),
#  (1,
#   'Arménie',
#   2013,
#   2657,
#   'Boissons Fermentés',
#   'vegetal',
#   0.0,
#   None,
#   None,
#   108660.5),
#  (1,
#   'Arménie',
#   2013,
#   2658,
#   'Boissons Alcooliques',
#   'vegetal',
#   1.0,
#   None,
#   None,
#   184722.85000000003),
#  (1,
#   'Arménie',
#   2013,
#   2680,
#   'Aliments pour enfants',
#   'vegetal',
#   2.0,
#   0.07,
#   0.01,
#   173856.8),
#  (1,
#   'Arménie',
#   2013,
#   2731,
#   'Viande de Bovins',
#   'animal',
#   114.0,
#   7.97,
#   8.88,
#   21362654.3),
#  (1,
#   'Arménie',
#   2013,
#   2732,
#   "Viande d'Ovins/Caprins",
#   'animal',
#   22.0,
#   1.12,
#   1.89,
#   3281547.1),
#  (1,
#   'Arménie',
#   2013,
#   2733,
#   'Viande de Suides',
#   'animal',
#   72.0,
#   2.53,
#   6.72,
#   10507470.35),
#  (1,
#   'Arménie',
#   2013,
#   2734,
#   'Viande de Volailles',
#   'animal',
#   45.0,
#   4.51,
#   2.82,
#   14506176.75),
#  (1, 'Arménie', 2013, 2735, 'Viande, Autre', 'animal', 0.0, 0.0, 0.0, 0.0),
#  (1,
#   'Arménie',
#   2013,
#   2736,
#   'Abats Comestible',
#   'animal',
#   14.0,
#   2.25,
#   0.39,
#   4987516.95),
#  (1,
#   'Arménie',
#   2013,
#   2737,
#   'Graisses Animales Crue',
#   'animal',
#   78.0,
#   0.22,
#   8.63,
#   4161697.15),
#  (1,
#   'Arménie',
#   2013,
#   2740,
#   'Beurre, Ghee',
#   'animal',
#   35.0,
#   0.04,
#   3.9,
#   1912424.8),
#  (1, 'Arménie', 2013, 2743, 'Crème', 'animal', 0.0, 0.0, 0.01, 10866.05),
#  (1, 'Arménie', 2013, 2744, 'Oeufs', 'animal', 45.0, 3.43, 3.15, 12702412.45),
#  (1,
#   'Arménie',
#   2013,
#   2745,
#   'Miel',
#   'vegetal',
#   6.0,
#   0.01,
#   None,
#   760623.4999999999),
#  (1,
#   'Arménie',
#   2013,
#   2761,
#   'Poissons Eau Douce',
#   'animal',
#   6.0,
#   0.98,
#   0.22,
#   3564064.4),
#  (1,
#   'Arménie',
#   2013,
#   2762,
#   'Perciform',
#   'animal',
#   0.0,
#   0.03,
#   0.02,
#   76062.35000000002),
#  (1,
#   'Arménie',
#   2013,
#   2763,
#   'Poissons Pelagiques',
#   'animal',
#   2.0,
#   0.25,
#   0.1,
#   901882.15),
#  (1,
#   'Arménie',
#   2013,
#   2764,
#   'Poissons Marins, Autres',
#   'animal',
#   0.0,
#   0.05,
#   0.01,
#   195588.9),
#  (1, 'Arménie', 2013, 2765, 'Crustacés', 'animal', 0.0, 0.0, 0.0, 21732.1),
#  (1, 'Arménie', 2013, 2766, 'Cephalopodes', 'animal', 0.0, 0.0, 0.0, 0.0),
#  (1,
#   'Arménie',
#   2013,
#   2767,
#   'Mollusques, Autres',
#   'animal',
#   0.0,
#   0.0,
#   0.0,
#   0.0),
#  (1,
#   'Arménie',
#   2013,
#   2769,
#   'Animaux Aquatiques Autre',
#   'animal',
#   0.0,
#   0.0,
#   0.0,
#   0.0),
#  (1,
#   'Arménie',
#   2013,
#   2775,
#   'Plantes Aquatiques',
#   'animal',
#   0.0,
#   0.0,
#   0.0,
#   0.0),
#  (1,
#   'Arménie',
#   2013,
#   2781,
#   'Huiles de Poissons',
#   'animal',
#   0.0,
#   0.0,
#   0.0,
#   0.0),
#  (1,
#   'Arménie',
#   2013,
#   2782,
#   'Huiles de Foie de Poisso',
#   'animal',
#   0.0,
#   0.0,
#   0.0,
#   0.0),
#  (1,
#   'Arménie',
#   2013,
#   2805,
#   'Riz (Eq Blanchi)',
#   'vegetal',
#   34.0,
#   0.66,
#   0.11,
#   3455403.9),
#  (1,
#   'Arménie',
#   2013,
#   2848,
#   'Lait - Excl Beurre',
#   'animal',
#   351.0,
#   19.86,
#   20.89,
#   227133043.15),
#  (1, 'Arménie', 2013, 2899, 'Miscellanees', 'vegetal', 3.0, 0.1, 0.04, None),
#  (2,
#   'Afghanistan',
#   2013,
#   2511,
#   'Blé',
#   'vegetal',
#   1369.0,
#   36.91,
#   4.69,
#   1786801640.4),
#  (2,
#   'Afghanistan',
#   2013,
#   2513,
#   'Orge',
#   'vegetal',
#   26.0,
#   0.79,
#   0.24,
#   32562321.6),
#  (2,
#   'Afghanistan',
#   2013,
#   2514,
#   'Maïs',
#   'vegetal',
#   21.0,
#   0.56,
#   0.3,
#   27878700.0),
#  (2,
#   'Afghanistan',
#   2013,
#   2517,
#   'Millet',
#   'vegetal',
#   3.0,
#   0.08,
#   0.02,
#   4460592.0),
#  (2,
#   'Afghanistan',
#   2013,
#   2520,
#   'Céréales, Autres',
#   'vegetal',
#   0.0,
#   0.0,
#   0.0,
#   0.0),
#  (2,
#   'Afghanistan',
#   2013,
#   2531,
#   'Pommes de Terre',
#   'vegetal',
#   15.0,
#   0.25,
#   0.04,
#   83970644.4),
#  (2,
#   'Afghanistan',
#   2013,
#   2542,
#   'Sucre Eq Brut',
#   'vegetal',
#   84.0,
#   None,
#   None,
#   93114858.0),
#  (2,
#   'Afghanistan',
#   2013,
#   2543,
#   'Edulcorants Autres',
#   'vegetal',
#   2.0,
#   None,
#   None,
#   5910284.4),
#  (2,
#   'Afghanistan',
#   2013,
#   2549,
#   'Légumineuses Autres',
#   'vegetal',
#   23.0,
#   1.56,
#   0.14,
#   27209611.2),
#  (2,
#   'Afghanistan',
#   2013,
#   2551,
#   'Noix',
#   'vegetal',
#   12.0,
#   0.38,
#   1.07,
#   16169646.0),
#  (2,
#   'Afghanistan',
#   2013,
#   2560,
#   'Coco (Incl Coprah)',
#   'vegetal',
#   0.0,
#   0.0,
#   0.0,
#   0.0),
#  (2,
#   'Afghanistan',
#   2013,
#   2561,
#   'Sésame',
#   'vegetal',
#   9.0,
#   0.27,
#   0.77,
#   5798769.6),
#  (2, 'Afghanistan', 2013, 2563, 'Olives', 'vegetal', 0.0, 0.0, 0.03, 669088.8),
#  (2,
#   'Afghanistan',
#   2013,
#   2571,
#   'Huile de Soja',
#   'vegetal',
#   13.0,
#   None,
#   1.46,
#   5910284.4),
#  (2,
#   'Afghanistan',
#   2013,
#   2572,
#   "Huile d'Arachide",
#   'vegetal',
#   0.0,
#   None,
#   0.0,
#   0.0),
#  (2,
#   'Afghanistan',
#   2013,
#   2573,
#   'Huile de Tournesol',
#   'vegetal',
#   18.0,
#   None,
#   2.06,
#   8363610.0),
#  (2,
#   'Afghanistan',
#   2013,
#   2574,
#   'Huile de Colza&Moutarde',
#   'vegetal',
#   2.0,
#   None,
#   0.18,
#   780603.6),
#  (2,
#   'Afghanistan',
#   2013,
#   2575,
#   'Huile Graines de Coton',
#   'vegetal',
#   3.0,
#   None,
#   0.34,
#   1338177.6),
#  (2,
#   'Afghanistan',
#   2013,
#   2577,
#   'Huile de Palme',
#   'vegetal',
#   51.0,
#   None,
#   5.74,
#   23306593.2),
#  (2,
#   'Afghanistan',
#   2013,
#   2579,
#   'Huile de Sésame',
#   'vegetal',
#   1.0,
#   None,
#   0.13,
#   557574.0),
#  (2,
#   'Afghanistan',
#   2013,
#   2580,
#   "Huile d'Olive",
#   'vegetal',
#   0.0,
#   None,
#   0.05,
#   223029.6),
#  (2,
#   'Afghanistan',
#   2013,
#   2586,
#   'Huil Plantes Oleif Autr',
#   'vegetal',
#   2.0,
#   0.0,
#   0.21,
#   892118.4),
#  (2, 'Afghanistan', 2013, 2601, 'Tomates', 'vegetal', 0.0, 0.0, 0.0, 0.0),
#  (2,
#   'Afghanistan',
#   2013,
#   2605,
#   'Légumes, Autres',
#   'vegetal',
#   17.0,
#   0.85,
#   0.13,
#   323058375.6),
#  (2,
#   'Afghanistan',
#   2013,
#   2611,
#   'Oranges, Mandarines',
#   'vegetal',
#   4.0,
#   0.07,
#   0.01,
#   52969530.0),
#  (2,
#   'Afghanistan',
#   2013,
#   2614,
#   'Agrumes, Autres',
#   'vegetal',
#   1.0,
#   0.02,
#   0.01,
#   14385409.2),
#  (2,
#   'Afghanistan',
#   2013,
#   2615,
#   'Bananes',
#   'vegetal',
#   4.0,
#   0.05,
#   0.02,
#   30108996.0),
#  (2,
#   'Afghanistan',
#   2013,
#   2617,
#   'Pommes',
#   'vegetal',
#   3.0,
#   0.02,
#   0.01,
#   24756285.6),
#  (2, 'Afghanistan', 2013, 2618, 'Ananas', 'vegetal', 0.0, None, None, 0.0),
#  (2, 'Afghanistan', 2013, 2619, 'Dattes', 'vegetal', 0.0, 0.0, 0.0, 223029.6),
#  (2,
#   'Afghanistan',
#   2013,
#   2620,
#   'Raisin',
#   'vegetal',
#   29.0,
#   0.27,
#   0.12,
#   176193384.0),
#  (2,
#   'Afghanistan',
#   2013,
#   2625,
#   'Fruits, Autres',
#   'vegetal',
#   9.0,
#   0.14,
#   0.06,
#   81294289.2),
#  (2, 'Afghanistan', 2013, 2630, 'Café', 'vegetal', 0.0, 0.0, None, 0.0),
#  (2,
#   'Afghanistan',
#   2013,
#   2633,
#   'Feve de Cacao',
#   'vegetal',
#   0.0,
#   0.01,
#   0.04,
#   223029.6),
#  (2, 'Afghanistan', 2013, 2635, 'Thé', 'vegetal', 4.0, 0.96, None, 38918665.2),
#  (2, 'Afghanistan', 2013, 2640, 'Poivre', 'vegetal', 0.0, 0.0, 0.0, 0.0),
#  (2,
#   'Afghanistan',
#   2013,
#   2645,
#   'Épices, Autres',
#   'vegetal',
#   2.0,
#   0.11,
#   0.1,
#   2899384.8),
#  (2, 'Afghanistan', 2013, 2655, 'Vin', 'vegetal', 0.0, None, None, 0.0),
#  (2, 'Afghanistan', 2013, 2656, 'Bière', 'vegetal', 0.0, 0.0, None, 1003633.2),
#  (2,
#   'Afghanistan',
#   2013,
#   2658,
#   'Boissons Alcooliques',
#   'vegetal',
#   0.0,
#   None,
#   None,
#   0.0),
#  (2,
#   'Afghanistan',
#   2013,
#   2680,
#   'Aliments pour enfants',
#   'vegetal',
#   1.0,
#   0.03,
#   0.01,
#   669088.8),
#  (2,
#   'Afghanistan',
#   2013,
#   2731,
#   'Viande de Bovins',
#   'animal',
#   27.0,
#   1.89,
#   2.1,
#   51185293.2),
#  (2,
#   'Afghanistan',
#   2013,
#   2732,
#   "Viande d'Ovins/Caprins",
#   'animal',
#   31.0,
#   1.91,
#   2.55,
#   54865281.6),
#  (2,
#   'Afghanistan',
#   2013,
#   2734,
#   'Viande de Volailles',
#   'animal',
#   9.0,
#   0.87,
#   0.53,
#   27321126.0),
#  (2,
#   'Afghanistan',
#   2013,
#   2735,
#   'Viande, Autre',
#   'animal',
#   1.0,
#   0.17,
#   0.06,
#   4237562.4),
#  (2,
#   'Afghanistan',
#   2013,
#   2736,
#   'Abats Comestible',
#   'animal',
#   5.0,
#   0.77,
#   0.2,
#   19180545.6),
#  (2,
#   'Afghanistan',
#   2013,
#   2737,
#   'Graisses Animales Crue',
#   'animal',
#   12.0,
#   0.01,
#   1.31,
#   5464225.2),
#  (2,
#   'Afghanistan',
#   2013,
#   2740,
#   'Beurre, Ghee',
#   'animal',
#   23.0,
#   0.03,
#   2.61,
#   13047231.6),
#  (2, 'Afghanistan', 2013, 2743, 'Crème', 'animal', 3.0, 0.04, 0.32, 6690888.0),
#  (2,
#   'Afghanistan',
#   2013,
#   2744,
#   'Oeufs',
#   'animal',
#   5.0,
#   0.38,
#   0.36,
#   14496924.0),
#  (2, 'Afghanistan', 2013, 2745, 'Miel', 'vegetal', 1.0, 0.0, None, 780603.6),
#  (2,
#   'Afghanistan',
#   2013,
#   2761,
#   'Poissons Eau Douce',
#   'animal',
#   0.0,
#   0.02,
#   0.0,
#   780603.6),
#  (2,
#   'Afghanistan',
#   2013,
#   2805,
#   'Riz (Eq Blanchi)',
#   'vegetal',
#   141.0,
#   2.7,
#   0.27,
#   154113453.6),
#  (2,
#   'Afghanistan',
#   2013,
#   2848,
#   'Lait - Excl Beurre',
#   'animal',
#   100.0,
#   6.12,
#   5.19,
#   693956600.4),
#  (2,
#   'Afghanistan',
#   2013,
#   2899,
#   'Miscellanees',
#   'vegetal',
#   1.0,
#   0.02,
#   0.02,
#   None),
#  (3,
#   'Albanie',
#   2013,
#   2511,
#   'Blé',
#   'vegetal',
#   1056.0,
#   33.64,
#   5.85,
#   160565222.79999998),
#  (3, 'Albanie', 2013, 2513, 'Orge', 'vegetal', 1.0, 0.03, 0.0, 185303.2),
#  (3, 'Albanie', 2013, 2514, 'Maïs', 'vegetal', 13.0, 0.31, 0.04, 2073079.55),
#  (3, 'Albanie', 2013, 2515, 'Seigle', 'vegetal', 5.0, 0.13, 0.02, 799120.05),
#  (3, 'Albanie', 2013, 2516, 'Avoine', 'vegetal', 1.0, 0.03, 0.01, 150558.85),
#  (3,
#   'Albanie',
#   2013,
#   2520,
#   'Céréales, Autres',
#   'vegetal',
#   0.0,
#   0.01,
#   0.0,
#   92651.6),
#  (3,
#   'Albanie',
#   2013,
#   2531,
#   'Pommes de Terre',
#   'vegetal',
#   77.0,
#   1.89,
#   0.11,
#   47785062.7),
#  (3, 'Albanie', 2013, 2532, 'Manioc', 'vegetal', 0.0, None, None, 0.0),
#  (3,
#   'Albanie',
#   2013,
#   2533,
#   'Patates douces',
#   'vegetal',
#   1.0,
#   0.01,
#   0.0,
#   393769.3),
#  (3, 'Albanie', 2013, 2534, 'Racines nda', 'vegetal', 0.0, None, None, 0.0),
#  (3,
#   'Albanie',
#   2013,
#   2542,
#   'Sucre Eq Brut',
#   'vegetal',
#   173.0,
#   None,
#   None,
#   20267537.5),
#  (3,
#   'Albanie',
#   2013,
#   2543,
#   'Edulcorants Autres',
#   'vegetal',
#   16.0,
#   None,
#   None,
#   33806252.55),
#  (3,
#   'Albanie',
#   2013,
#   2546,
#   'Haricots',
#   'vegetal',
#   46.0,
#   2.92,
#   0.22,
#   5837050.8),
#  (3, 'Albanie', 2013, 2547, 'Pois', 'vegetal', 0.0, 0.0, None, 0.0),
#  (3,
#   'Albanie',
#   2013,
#   2549,
#   'Légumineuses Autres',
#   'vegetal',
#   3.0,
#   0.22,
#   0.02,
#   393769.3),
#  (3, 'Albanie', 2013, 2551, 'Noix', 'vegetal', 27.0, 0.61, 2.07, 4875790.45),
#  (3, 'Albanie', 2013, 2555, 'Soja', 'vegetal', 0.0, None, None, 0.0),
#  (3,
#   'Albanie',
#   2013,
#   2556,
#   'Arachides Decortiquees',
#   'vegetal',
#   2.0,
#   0.11,
#   0.2,
#   173721.75),
#  (3,
#   'Albanie',
#   2013,
#   2558,
#   'Graines Colza/Moutarde',
#   'vegetal',
#   0.0,
#   0.0,
#   0.0,
#   0.0),
#  (3,
#   'Albanie',
#   2013,
#   2560,
#   'Coco (Incl Coprah)',
#   'vegetal',
#   0.0,
#   0.0,
#   0.01,
#   11581.45),
#  (3, 'Albanie', 2013, 2563, 'Olives', 'vegetal', 69.0, 0.69, 6.99, 26637335.0),
#  (3,
#   'Albanie',
#   2013,
#   2571,
#   'Huile de Soja',
#   'vegetal',
#   3.0,
#   None,
#   0.32,
#   138977.4),
#  (3,
#   'Albanie',
#   2013,
#   2572,
#   "Huile d'Arachide",
#   'vegetal',
#   0.0,
#   None,
#   0.02,
#   11581.45),
#  (3,
#   'Albanie',
#   2013,
#   2573,
#   'Huile de Tournesol',
#   'vegetal',
#   121.0,
#   0.0,
#   13.66,
#   5779143.55),
#  (3,
#   'Albanie',
#   2013,
#   2574,
#   'Huile de Colza&Moutarde',
#   'vegetal',
#   1.0,
#   None,
#   0.07,
#   34744.35),
#  (3, 'Albanie', 2013, 2577, 'Huile de Palme', 'vegetal', 0.0, 0.0, 0.0, 0.0),
#  (3,
#   'Albanie',
#   2013,
#   2580,
#   "Huile d'Olive",
#   'vegetal',
#   14.0,
#   None,
#   1.55,
#   660142.6499999999),
#  (3,
#   'Albanie',
#   2013,
#   2582,
#   'Huile de Germe de Maïs',
#   'vegetal',
#   7.0,
#   None,
#   0.74,
#   312699.15),
#  (3,
#   'Albanie',
#   2013,
#   2586,
#   'Huil Plantes Oleif Autr',
#   'vegetal',
#   26.0,
#   0.02,
#   2.97,
#   1297122.4),
#  (3,
#   'Albanie',
#   2013,
#   2601,
#   'Tomates',
#   'vegetal',
#   28.0,
#   1.33,
#   0.33,
#   67589342.2),
#  (3,
#   'Albanie',
#   2013,
#   2602,
#   'Oignons',
#   'vegetal',
#   25.0,
#   0.89,
#   0.16,
#   34385325.05),
#  (3,
#   'Albanie',
#   2013,
#   2605,
#   'Légumes, Autres',
#   'vegetal',
#   98.0,
#   4.07,
#   0.76,
#   181886672.25000003),
#  (3,
#   'Albanie',
#   2013,
#   2611,
#   'Oranges, Mandarines',
#   'vegetal',
#   11.0,
#   0.21,
#   0.03,
#   14581045.55),
#  (3,
#   'Albanie',
#   2013,
#   2612,
#   'Citrons & Limes',
#   'vegetal',
#   1.0,
#   0.03,
#   0.01,
#   1795124.75),
#  (3,
#   'Albanie',
#   2013,
#   2613,
#   'Pamplemousse',
#   'vegetal',
#   0.0,
#   0.0,
#   None,
#   138977.4),
#  (3,
#   'Albanie',
#   2013,
#   2614,
#   'Agrumes, Autres',
#   'vegetal',
#   0.0,
#   0.0,
#   None,
#   277954.8),
#  (3, 'Albanie', 2013, 2615, 'Bananes', 'vegetal', 10.0, 0.12, 0.05, 7226824.8),
#  (3,
#   'Albanie',
#   2013,
#   2616,
#   'Bananes plantains',
#   'vegetal',
#   0.0,
#   None,
#   None,
#   196884.65),
#  (3, 'Albanie', 2013, 2617, 'Pommes', 'vegetal', 33.0, 0.2, 0.27, 28490367.0),
#  (3, 'Albanie', 2013, 2618, 'Ananas', 'vegetal', 0.0, None, None, 57907.25),
#  (3, 'Albanie', 2013, 2619, 'Dattes', 'vegetal', 16.0, 0.16, 0.04, 4400951.0),
#  (3, 'Albanie', 2013, 2620, 'Raisin', 'vegetal', 86.0, 0.92, 0.4, 55776263.2),
#  (3,
#   'Albanie',
#   2013,
#   2625,
#   'Fruits, Autres',
#   'vegetal',
#   63.0,
#   0.92,
#   0.43,
#   51514289.6),
#  (3, 'Albanie', 2013, 2630, 'Café', 'vegetal', 3.0, 0.42, None, 2872199.6),
#  (3,
#   'Albanie',
#   2013,
#   2633,
#   'Feve de Cacao',
#   'vegetal',
#   13.0,
#   0.16,
#   1.17,
#   833864.4),
#  (3, 'Albanie', 2013, 2635, 'Thé', 'vegetal', 0.0, 0.01, None, 92651.6),
#  (3, 'Albanie', 2013, 2640, 'Poivre', 'vegetal', 0.0, 0.0, 0.0, 0.0),
#  (3, 'Albanie', 2013, 2641, 'Piments', 'vegetal', 0.0, 0.0, 0.0, 11581.45),
#  (3,
#   'Albanie',
#   2013,
#   2645,
#   'Épices, Autres',
#   'vegetal',
#   0.0,
#   0.01,
#   0.01,
#   46325.8),
#  (3, 'Albanie', 2013, 2655, 'Vin', 'vegetal', 15.0, None, None, 9230415.65),
#  (3, 'Albanie', 2013, 2656, 'Bière', 'vegetal', 36.0, 0.37, None, 31246752.1),
#  (3,
#   'Albanie',
#   2013,
#   2657,
#   'Boissons Fermentés',
#   'vegetal',
#   0.0,
#   None,
#   None,
#   0.0),
#  (3,
#   'Albanie',
#   2013,
#   2658,
#   'Boissons Alcooliques',
#   'vegetal',
#   21.0,
#   None,
#   None,
#   3069084.25),
#  (3,
#   'Albanie',
#   2013,
#   2680,
#   'Aliments pour enfants',
#   'vegetal',
#   1.0,
#   0.04,
#   0.01,
#   104233.05),
#  (3,
#   'Albanie',
#   2013,
#   2731,
#   'Viande de Bovins',
#   'animal',
#   101.0,
#   9.36,
#   6.78,
#   26058262.5),
#  (3,
#   'Albanie',
#   2013,
#   2732,
#   "Viande d'Ovins/Caprins",
#   'animal',
#   85.0,
#   5.66,
#   6.72,
#   17742781.4),
#  (3,
#   'Albanie',
#   2013,
#   2733,
#   'Viande de Suides',
#   'animal',
#   83.0,
#   2.73,
#   7.9,
#   12600617.6),
#  (3,
#   'Albanie',
#   2013,
#   2734,
#   'Viande de Volailles',
#   'animal',
#   67.0,
#   4.94,
#   5.12,
#   15322258.35),
#  (3,
#   'Albanie',
#   2013,
#   2735,
#   'Viande, Autre',
#   'animal',
#   0.0,
#   0.02,
#   0.01,
#   46325.8),
#  (3,
#   'Albanie',
#   2013,
#   2736,
#   'Abats Comestible',
#   'animal',
#   11.0,
#   1.6,
#   0.4,
#   4053507.5),
#  (3,
#   'Albanie',
#   2013,
#   2737,
#   'Graisses Animales Crue',
#   'animal',
#   28.0,
#   0.1,
#   3.11,
#   1528751.4),
#  (3,
#   'Albanie',
#   2013,
#   2740,
#   'Beurre, Ghee',
#   'animal',
#   23.0,
#   0.03,
#   2.65,
#   1378192.55),
#  (3, 'Albanie', 2013, 2743, 'Crème', 'animal', 0.0, 0.0, 0.02, 34744.35),
#  (3, 'Albanie', 2013, 2744, 'Oeufs', 'animal', 46.0, 3.65, 3.28, 14418905.25),
#  (3, 'Albanie', 2013, 2745, 'Miel', 'vegetal', 8.0, 0.01, None, 1100237.75),
#  (3,
#   'Albanie',
#   2013,
#   2761,
#   'Poissons Eau Douce',
#   'animal',
#   1.0,
#   0.22,
#   0.05,
#   880190.2),
#  (3, 'Albanie', 2013, 2762, 'Perciform', 'animal', 1.0, 0.22, 0.02, 1134982.1),
#  (3,
#   'Albanie',
#   2013,
#   2763,
#   'Poissons Pelagiques',
#   'animal',
#   4.0,
#   0.47,
#   0.18,
#   1667728.8),
#  (3,
#   'Albanie',
#   2013,
#   2764,
#   'Poissons Marins, Autres',
#   'animal',
#   1.0,
#   0.19,
#   0.04,
#   775957.15),
#  (3, 'Albanie', 2013, 2765, 'Crustacés', 'animal', 0.0, 0.09, 0.0, 370606.4),
#  (3,
#   'Albanie',
#   2013,
#   2766,
#   'Cephalopodes',
#   'animal',
#   1.0,
#   0.15,
#   0.01,
#   428513.65),
#  (3,
#   'Albanie',
#   2013,
#   2767,
#   'Mollusques, Autres',
#   'animal',
#   0.0,
#   0.02,
#   0.0,
#   382187.85),
#  (3,
#   'Albanie',
#   2013,
#   2769,
#   'Animaux Aquatiques Autre',
#   'animal',
#   0.0,
#   0.0,
#   0.0,
#   0.0),
#  (3,
#   'Albanie',
#   2013,
#   2775,
#   'Plantes Aquatiques',
#   'animal',
#   0.0,
#   0.0,
#   0.0,
#   0.0),
#  (3,
#   'Albanie',
#   2013,
#   2781,
#   'Huiles de Poissons',
#   'animal',
#   0.0,
#   0.0,
#   0.0,
#   0.0),
#  (3,
#   'Albanie',
#   2013,
#   2782,
#   'Huiles de Foie de Poisso',
#   'animal',
#   0.0,
#   0.0,
#   0.0,
#   0.0),
#  (3,
#   'Albanie',
#   2013,
#   2805,
#   'Riz (Eq Blanchi)',
#   'vegetal',
#   68.0,
#   1.34,
#   0.16,
#   9010368.1),
#  (3,
#   'Albanie',
#   2013,
#   2848,
#   'Lait - Excl Beurre',
#   'animal',
#   533.0,
#   29.96,
#   31.43,
#   351751799.40000004),
#  (3, 'Albanie', 2013, 2899, 'Miscellanees', 'vegetal', 5.0, 0.13, 0.06, None),
#  (4,
#   'Algérie',
#   2013,
#   2511,
#   'Blé',
#   'vegetal',
#   1424.0,
#   42.97,
#   5.34,
#   2653530786.4),
#  (4, 'Algérie', 2013, 2513, 'Orge', 'vegetal', 94.0, 2.58, 0.29, 188617925.6),
#  (4, 'Algérie', 2013, 2514, 'Maïs', 'vegetal', 129.0, 3.18, 1.12, 228831610.8),
#  (4, 'Algérie', 2013, 2515, 'Seigle', 'vegetal', 0.0, 0.0, 0.0, 0.0),
#  (4, 'Algérie', 2013, 2516, 'Avoine', 'vegetal', 0.0, 0.0, 0.0, 143109.2),
#  (4, 'Algérie', 2013, 2518, 'Sorgho', 'vegetal', 1.0, 0.02, 0.0, 1001764.4),
#  (4,
#   'Algérie',
#   2013,
#   2520,
#   'Céréales, Autres',
#   'vegetal',
#   0.0,
#   0.01,
#   0.0,
#   429327.6),
#  (4,
#   'Algérie',
#   2013,
#   2531,
#   'Pommes de Terre',
#   'vegetal',
#   126.0,
#   2.66,
#   0.18,
#   927061397.6),
#  (4, 'Algérie', 2013, 2532, 'Manioc', 'vegetal', 0.0, None, None, 0.0),
#  (4, 'Algérie', 2013, 2534, 'Racines nda', 'vegetal', 0.0, 0.0, None, 0.0),
#  (4,
#   'Algérie',
#   2013,
#   2542,
#   'Sucre Eq Brut',
#   'vegetal',
#   258.0,
#   None,
#   None,
#   397557357.6),
#  (4,
#   'Algérie',
#   2013,
#   2543,
#   'Edulcorants Autres',
#   'vegetal',
#   6.0,
#   None,
#   None,
#   8586552.0),
#  (4,
#   'Algérie',
#   2013,
#   2546,
#   'Haricots',
#   'vegetal',
#   14.0,
#   0.92,
#   0.06,
#   22181926.0),
#  (4, 'Algérie', 2013, 2547, 'Pois', 'vegetal', 4.0, 0.28, 0.01, 6583023.2),
#  (4,
#   'Algérie',
#   2013,
#   2549,
#   'Légumineuses Autres',
#   'vegetal',
#   61.0,
#   3.85,
#   0.44,
#   90301905.2),
#  (4, 'Algérie', 2013, 2551, 'Noix', 'vegetal', 13.0, 0.43, 1.18, 25759656.0),
#  (4, 'Algérie', 2013, 2555, 'Soja', 'vegetal', 0.0, 0.0, None, 0.0),
#  (4,
#   'Algérie',
#   2013,
#   2556,
#   'Arachides Decortiquees',
#   'vegetal',
#   5.0,
#   0.21,
#   0.38,
#   4007057.600000001),
#  (4,
#   'Algérie',
#   2013,
#   2558,
#   'Graines Colza/Moutarde',
#   'vegetal',
#   0.0,
#   0.0,
#   0.0,
#   0.0),
#  (4,
#   'Algérie',
#   2013,
#   2560,
#   'Coco (Incl Coprah)',
#   'vegetal',
#   0.0,
#   0.0,
#   0.02,
#   858655.2),
#  (4, 'Algérie', 2013, 2561, 'Sésame', 'vegetal', 2.0, 0.06, 0.16, 1717310.4),
#  (4, 'Algérie', 2013, 2562, 'Palmistes', 'vegetal', 0.0, None, 0.0, 0.0),
#  (4, 'Algérie', 2013, 2563, 'Olives', 'vegetal', 12.0, 0.15, 1.36, 69694180.4),
#  (4,
#   'Algérie',
#   2013,
#   2570,
#   'Plantes Oleiferes, Autre',
#   'vegetal',
#   0.0,
#   None,
#   None,
#   None),
#  (4,
#   'Algérie',
#   2013,
#   2571,
#   'Huile de Soja',
#   'vegetal',
#   181.0,
#   None,
#   20.48,
#   107045681.6),
#  (4,
#   'Algérie',
#   2013,
#   2572,
#   "Huile d'Arachide",
#   'vegetal',
#   12.0,
#   None,
#   1.37,
#   7155460.0),
#  (4,
#   'Algérie',
#   2013,
#   2573,
#   'Huile de Tournesol',
#   'vegetal',
#   48.0,
#   None,
#   5.41,
#   28335621.6),
#  (4,
#   'Algérie',
#   2013,
#   2574,
#   'Huile de Colza&Moutarde',
#   'vegetal',
#   11.0,
#   0.01,
#   1.2,
#   6583023.2),
#  (4,
#   'Algérie',
#   2013,
#   2577,
#   'Huile de Palme',
#   'vegetal',
#   18.0,
#   None,
#   2.03,
#   10590080.8),
#  (4,
#   'Algérie',
#   2013,
#   2578,
#   'Huile de Coco',
#   'vegetal',
#   1.0,
#   None,
#   0.07,
#   429327.6),
#  (4, 'Algérie', 2013, 2579, 'Huile de Sésame', 'vegetal', 0.0, None, 0.0, 0.0),
#  (4,
#   'Algérie',
#   2013,
#   2580,
#   "Huile d'Olive",
#   'vegetal',
#   42.0,
#   None,
#   4.74,
#   24757891.6),
#  (4,
#   'Algérie',
#   2013,
#   2582,
#   'Huile de Germe de Maïs',
#   'vegetal',
#   1.0,
#   None,
#   0.13,
#   715546.0),
#  (4,
#   'Algérie',
#   2013,
#   2586,
#   'Huil Plantes Oleif Autr',
#   'vegetal',
#   47.0,
#   0.04,
#   5.3,
#   28478730.8),
#  (4,
#   'Algérie',
#   2013,
#   2601,
#   'Tomates',
#   'vegetal',
#   16.0,
#   0.79,
#   0.17,
#   391546771.2),
#  (4,
#   'Algérie',
#   2013,
#   2602,
#   'Oignons',
#   'vegetal',
#   35.0,
#   0.98,
#   0.09,
#   466106664.4),
#  (4,
#   'Algérie',
#   2013,
#   2605,
#   'Légumes, Autres',
#   'vegetal',
#   73.0,
#   3.43,
#   0.47,
#   1513522899.2),
#  (4,
#   'Algérie',
#   2013,
#   2611,
#   'Oranges, Mandarines',
#   'vegetal',
#   24.0,
#   0.33,
#   0.2,
#   407431892.4),
#  (4,
#   'Algérie',
#   2013,
#   2612,
#   'Citrons & Limes',
#   'vegetal',
#   1.0,
#   0.02,
#   0.02,
#   27333857.2),
#  (4,
#   'Algérie',
#   2013,
#   2613,
#   'Pamplemousse',
#   'vegetal',
#   0.0,
#   0.0,
#   0.0,
#   1001764.4),
#  (4,
#   'Algérie',
#   2013,
#   2614,
#   'Agrumes, Autres',
#   'vegetal',
#   0.0,
#   0.0,
#   0.0,
#   3291511.6),
#  (4,
#   'Algérie',
#   2013,
#   2615,
#   'Bananes',
#   'vegetal',
#   10.0,
#   0.17,
#   0.02,
#   90158796.0),
#  (4,
#   'Algérie',
#   2013,
#   2616,
#   'Bananes plantains',
#   'vegetal',
#   0.0,
#   0.0,
#   0.0,
#   0.0),
#  (4,
#   'Algérie',
#   2013,
#   2617,
#   'Pommes',
#   'vegetal',
#   18.0,
#   0.08,
#   0.11,
#   198349351.2),
#  (4, 'Algérie', 2013, 2618, 'Ananas', 'vegetal', 0.0, 0.0, 0.0, 3720839.2),
#  (4,
#   'Algérie',
#   2013,
#   2619,
#   'Dattes',
#   'vegetal',
#   101.0,
#   0.84,
#   0.21,
#   299527555.6),
#  (4,
#   'Algérie',
#   2013,
#   2620,
#   'Raisin',
#   'vegetal',
#   21.0,
#   0.22,
#   0.14,
#   186900615.2),
#  (4,
#   'Algérie',
#   2013,
#   2625,
#   'Fruits, Autres',
#   'vegetal',
#   39.0,
#   0.57,
#   0.26,
#   416447772.0),
#  (4, 'Algérie', 2013, 2630, 'Café', 'vegetal', 4.0, 0.6, None, 47226036.0),
#  (4,
#   'Algérie',
#   2013,
#   2633,
#   'Feve de Cacao',
#   'vegetal',
#   10.0,
#   0.22,
#   0.83,
#   15169575.2),
#  (4, 'Algérie', 2013, 2635, 'Thé', 'vegetal', 0.0, 0.09, None, 4722603.6),
#  (4, 'Algérie', 2013, 2640, 'Poivre', 'vegetal', 1.0, 0.03, 0.01, 1431092.0),
#  (4, 'Algérie', 2013, 2641, 'Piments', 'vegetal', 4.0, 0.18, 0.12, 6869241.6),
#  (4, 'Algérie', 2013, 2642, 'Girofles', 'vegetal', 0.0, 0.0, 0.0, 0.0),
#  (4,
#   'Algérie',
#   2013,
#   2645,
#   'Épices, Autres',
#   'vegetal',
#   2.0,
#   0.09,
#   0.09,
#   3577730.0),
#  (4, 'Algérie', 2013, 2655, 'Vin', 'vegetal', 0.0, None, None, 143109.2),
#  (4, 'Algérie', 2013, 2656, 'Bière', 'vegetal', 6.0, 0.07, None, 68692416.0),
#  (4,
#   'Algérie',
#   2013,
#   2657,
#   'Boissons Fermentés',
#   'vegetal',
#   0.0,
#   None,
#   None,
#   0.0),
#  (4,
#   'Algérie',
#   2013,
#   2658,
#   'Boissons Alcooliques',
#   'vegetal',
#   1.0,
#   None,
#   None,
#   2575965.6),
#  (4,
#   'Algérie',
#   2013,
#   2680,
#   'Aliments pour enfants',
#   'vegetal',
#   6.0,
#   0.23,
#   0.04,
#   7871006.0),
#  (4,
#   'Algérie',
#   2013,
#   2731,
#   'Viande de Bovins',
#   'animal',
#   25.0,
#   2.25,
#   1.76,
#   80141152.0),
#  (4,
#   'Algérie',
#   2013,
#   2732,
#   "Viande d'Ovins/Caprins",
#   'animal',
#   43.0,
#   2.81,
#   3.42,
#   110050974.8),
#  (4, 'Algérie', 2013, 2733, 'Viande de Suides', 'animal', 0.0, 0.0, 0.0, 0.0),
#  (4,
#   'Algérie',
#   2013,
#   2734,
#   'Viande de Volailles',
#   'animal',
#   26.0,
#   2.28,
#   1.75,
#   106187026.4),
#  (4,
#   'Algérie',
#   2013,
#   2735,
#   'Viande, Autre',
#   'animal',
#   1.0,
#   0.15,
#   0.08,
#   5151931.2),
#  (4,
#   'Algérie',
#   2013,
#   2736,
#   'Abats Comestible',
#   'animal',
#   4.0,
#   0.63,
#   0.18,
#   20750834.0),
#  (4,
#   'Algérie',
#   2013,
#   2737,
#   'Graisses Animales Crue',
#   'animal',
#   6.0,
#   0.0,
#   0.66,
#   3577730.0),
#  (4,
#   'Algérie',
#   2013,
#   2740,
#   'Beurre, Ghee',
#   'animal',
#   11.0,
#   0.01,
#   1.2,
#   7155460.0),
#  (4, 'Algérie', 2013, 2744, 'Oeufs', 'animal', 27.0, 2.3, 1.85, 115346015.2),
#  (4,
#   'Algérie',
#   2013,
#   2745,
#   'Miel',
#   'vegetal',
#   1.0,
#   0.0,
#   None,
#   2432856.4000000004),
#  (4,
#   'Algérie',
#   2013,
#   2761,
#   'Poissons Eau Douce',
#   'animal',
#   1.0,
#   0.08,
#   0.02,
#   4865712.800000001),
#  (4, 'Algérie', 2013, 2762, 'Perciform', 'animal', 0.0, 0.09, 0.01, 6010586.4),
#  (4,
#   'Algérie',
#   2013,
#   2763,
#   'Poissons Pelagiques',
#   'animal',
#   6.0,
#   0.87,
#   0.27,
#   36492846.0),
#  (4,
#   'Algérie',
#   2013,
#   2764,
#   'Poissons Marins, Autres',
#   'animal',
#   1.0,
#   0.12,
#   0.03,
#   6153695.6),
#  (4, 'Algérie', 2013, 2765, 'Crustacés', 'animal', 0.0, 0.03, 0.0, 1717310.4),
#  (4,
#   'Algérie',
#   2013,
#   2766,
#   'Cephalopodes',
#   'animal',
#   0.0,
#   0.02,
#   0.0,
#   715546.0),
#  (4,
#   'Algérie',
#   2013,
#   2767,
#   'Mollusques, Autres',
#   'animal',
#   0.0,
#   0.0,
#   0.0,
#   143109.2),
#  (4,
#   'Algérie',
#   2013,
#   2769,
#   'Animaux Aquatiques Autre',
#   'animal',
#   0.0,
#   0.0,
#   0.0,
#   0.0),
#  (4,
#   'Algérie',
#   2013,
#   2775,
#   'Plantes Aquatiques',
#   'animal',
#   0.0,
#   0.0,
#   0.0,
#   0.0),
#  (4,
#   'Algérie',
#   2013,
#   2781,
#   'Huiles de Poissons',
#   'animal',
#   0.0,
#   0.0,
#   0.0,
#   0.0),
#  (4,
#   'Algérie',
#   2013,
#   2782,
#   'Huiles de Foie de Poisso',
#   'animal',
#   0.0,
#   0.0,
#   0.0,
#   0.0),
#  (4,
#   'Algérie',
#   2013,
#   2805,
#   'Riz (Eq Blanchi)',
#   'vegetal',
#   30.0,
#   0.57,
#   0.04,
#   42503432.400000006),
#  (4,
#   'Algérie',
#   2013,
#   2848,
#   'Lait - Excl Beurre',
#   'animal',
#   227.0,
#   13.34,
#   11.13,
#   2025424507.6),
#  (4, 'Algérie', 2013, 2899, 'Miscellanees', 'vegetal', 2.0, 0.06, 0.03, None),
#  (7, 'Angola', 2013, 2511, 'Blé', 'vegetal', 286.0, 8.67, 1.04, 319134041.6),
#  (7, 'Angola', 2013, 2513, 'Orge', 'vegetal', 0.0, 0.0, None, 0.0),
#  (7,
#   'Angola',
#   2013,
#   2514,
#   'Maïs',
#   'vegetal',
#   338.0,
#   8.9,
#   3.64,
#   304086463.99999994),
#  (7, 'Angola', 2013, 2516, 'Avoine', 'vegetal', 0.0, 0.0, 0.0, 78372.8),
#  (7, 'Angola', 2013, 2517, 'Millet', 'vegetal', 11.0, 0.18, 0.05, 11050564.8),
#  (7, 'Angola', 2013, 2518, 'Sorgho', 'vegetal', 0.0, 0.0, 0.0, 0.0),
#  (7,
#   'Angola',
#   2013,
#   2531,
#   'Pommes de Terre',
#   'vegetal',
#   40.0,
#   0.84,
#   0.06,
#   159802139.2),
#  (7,
#   'Angola',
#   2013,
#   2532,
#   'Manioc',
#   'vegetal',
#   560.0,
#   4.72,
#   0.6,
#   1550997712.0),
#  (7,
#   'Angola',
#   2013,
#   2533,
#   'Patates douces',
#   'vegetal',
#   129.0,
#   1.75,
#   0.27,
#   385359057.6),
#  (7, 'Angola', 2013, 2534, 'Racines nda', 'vegetal', 0.0, None, None, 0.0),
#  (7,
#   'Angola',
#   2013,
#   2542,
#   'Sucre Eq Brut',
#   'vegetal',
#   137.0,
#   None,
#   None,
#   119205028.8),
#  (7,
#   'Angola',
#   2013,
#   2543,
#   'Edulcorants Autres',
#   'vegetal',
#   0.0,
#   None,
#   None,
#   78372.8),
#  (7,
#   'Angola',
#   2013,
#   2546,
#   'Haricots',
#   'vegetal',
#   81.0,
#   5.23,
#   0.37,
#   70222028.80000001),
#  (7, 'Angola', 2013, 2551, 'Noix', 'vegetal', 0.0, 0.01, 0.03, 705355.2),
#  (7, 'Angola', 2013, 2555, 'Soja', 'vegetal', 5.0, 0.54, 0.25, 4075385.6),
#  (7,
#   'Angola',
#   2013,
#   2556,
#   'Arachides Decortiquees',
#   'vegetal',
#   33.0,
#   1.38,
#   2.67,
#   17006897.6),
#  (7,
#   'Angola',
#   2013,
#   2560,
#   'Coco (Incl Coprah)',
#   'vegetal',
#   1.0,
#   0.01,
#   0.05,
#   1175592.0),
#  (7, 'Angola', 2013, 2561, 'Sésame', 'vegetal', 2.0, 0.06, 0.17, 1018846.4),
#  (7,
#   'Angola',
#   2013,
#   2571,
#   'Huile de Soja',
#   'vegetal',
#   87.0,
#   None,
#   9.89,
#   28292580.8),
#  (7,
#   'Angola',
#   2013,
#   2572,
#   "Huile d'Arachide",
#   'vegetal',
#   19.0,
#   None,
#   2.11,
#   6034705.6),
#  (7,
#   'Angola',
#   2013,
#   2573,
#   'Huile de Tournesol',
#   'vegetal',
#   5.0,
#   None,
#   0.6,
#   1724201.6),
#  (7,
#   'Angola',
#   2013,
#   2574,
#   'Huile de Colza&Moutarde',
#   'vegetal',
#   1.0,
#   None,
#   0.12,
#   313491.2),
#  (7,
#   'Angola',
#   2013,
#   2575,
#   'Huile Graines de Coton',
#   'vegetal',
#   1.0,
#   None,
#   0.07,
#   235118.4),
#  (7,
#   'Angola',
#   2013,
#   2576,
#   'Huile de Palmistes',
#   'vegetal',
#   8.0,
#   None,
#   0.9,
#   2586302.4),
#  (7,
#   'Angola',
#   2013,
#   2577,
#   'Huile de Palme',
#   'vegetal',
#   73.0,
#   None,
#   8.29,
#   23746958.399999995),
#  (7, 'Angola', 2013, 2578, 'Huile de Coco', 'vegetal', 0.0, None, 0.0, 0.0),
#  (7,
#   'Angola',
#   2013,
#   2580,
#   "Huile d'Olive",
#   'vegetal',
#   5.0,
#   None,
#   0.57,
#   1645828.8),
#  (7,
#   'Angola',
#   2013,
#   2582,
#   'Huile de Germe de Maïs',
#   'vegetal',
#   0.0,
#   None,
#   0.01,
#   0.0),
#  (7,
#   'Angola',
#   2013,
#   2586,
#   'Huil Plantes Oleif Autr',
#   'vegetal',
#   17.0,
#   0.01,
#   1.9,
#   5564468.8),
#  (7,
#   'Angola',
#   2013,
#   2601,
#   'Tomates',
#   'vegetal',
#   3.0,
#   0.15,
#   0.03,
#   37070334.400000006),
#  (7,
#   'Angola',
#   2013,
#   2602,
#   'Oignons',
#   'vegetal',
#   0.0,
#   0.01,
#   0.0,
#   2664675.2000000007),
#  (7,
#   'Angola',
#   2013,
#   2605,
#   'Légumes, Autres',
#   'vegetal',
#   35.0,
#   1.93,
#   0.22,
#   490535355.2),
#  (7,
#   'Angola',
#   2013,
#   2611,
#   'Oranges, Mandarines',
#   'vegetal',
#   0.0,
#   0.01,
#   0.0,
#   2194438.4000000004),
#  (7,
#   'Angola',
#   2013,
#   2614,
#   'Agrumes, Autres',
#   'vegetal',
#   10.0,
#   0.14,
#   0.1,
#   100003692.8),
#  (7,
#   'Angola',
#   2013,
#   2615,
#   'Bananes',
#   'vegetal',
#   88.0,
#   1.37,
#   0.19,
#   421332172.8),
#  (7, 'Angola', 2013, 2617, 'Pommes', 'vegetal', 1.0, 0.01, 0.01, 7837280.0),
#  (7, 'Angola', 2013, 2618, 'Ananas', 'vegetal', 25.0, 0.15, 0.09, 157450955.2),
#  (7, 'Angola', 2013, 2619, 'Dattes', 'vegetal', 0.0, None, None, 0.0),
#  (7, 'Angola', 2013, 2620, 'Raisin', 'vegetal', 0.0, 0.0, 0.0, 862100.8),
#  (7,
#   'Angola',
#   2013,
#   2625,
#   'Fruits, Autres',
#   'vegetal',
#   3.0,
#   0.03,
#   0.03,
#   18260862.4),
#  (7, 'Angola', 2013, 2630, 'Café', 'vegetal', 1.0, 0.11, None, 4780740.8),
#  (7,
#   'Angola',
#   2013,
#   2633,
#   'Feve de Cacao',
#   'vegetal',
#   3.0,
#   0.03,
#   0.28,
#   1097219.2000000002),
#  (7, 'Angola', 2013, 2635, 'Thé', 'vegetal', 0.0, 0.01, None, 235118.4),
#  (7, 'Angola', 2013, 2640, 'Poivre', 'vegetal', 0.0, 0.0, 0.0, 0.0),
#  (7, 'Angola', 2013, 2641, 'Piments', 'vegetal', 0.0, 0.0, 0.0, 0.0),
#  (7, 'Angola', 2013, 2642, 'Girofles', 'vegetal', 0.0, None, None, 0.0),
#  (7,
#   'Angola',
#   2013,
#   2645,
#   'Épices, Autres',
#   'vegetal',
#   0.0,
#   0.01,
#   0.01,
#   156745.6),
#  (7, 'Angola', 2013, 2655, 'Vin', 'vegetal', 9.0, None, None, 36600097.6),
#  (7, 'Angola', 2013, 2656, 'Bière', 'vegetal', 67.0, 0.77, None, 443276556.8),
#  (7,
#   'Angola',
#   2013,
#   2657,
#   'Boissons Fermentés',
#   'vegetal',
#   24.0,
#   0.08,
#   None,
#   147575982.39999998),
#  (7,
#   'Angola',
#   2013,
#   2658,
#   'Boissons Alcooliques',
#   'vegetal',
#   16.0,
#   None,
#   None,
#   15204323.2),
#  (7,
#   'Angola',
#   2013,
#   2680,
#   'Aliments pour enfants',
#   'vegetal',
#   3.0,
#   0.11,
#   0.02,
#   1959320.0),
#  (7,
#   'Angola',
#   2013,
#   2731,
#   'Viande de Bovins',
#   'animal',
#   36.0,
#   3.48,
#   2.37,
#   65989897.6),
#  (7,
#   'Angola',
#   2013,
#   2732,
#   "Viande d'Ovins/Caprins",
#   'animal',
#   5.0,
#   0.44,
#   0.32,
#   8464262.4),
#  (7,
#   'Angola',
#   2013,
#   2733,
#   'Viande de Suides',
#   'animal',
#   89.0,
#   2.47,
#   8.7,
#   69673419.2),
#  (7,
#   'Angola',
#   2013,
#   2734,
#   'Viande de Volailles',
#   'animal',
#   58.0,
#   5.84,
#   3.66,
#   135820062.39999998),
#  (7,
#   'Angola',
#   2013,
#   2735,
#   'Viande, Autre',
#   'animal',
#   1.0,
#   0.21,
#   0.03,
#   3291657.6),
#  (7,
#   'Angola',
#   2013,
#   2736,
#   'Abats Comestible',
#   'animal',
#   3.0,
#   0.56,
#   0.1,
#   9012871.999999998),
#  (7,
#   'Angola',
#   2013,
#   2737,
#   'Graisses Animales Crue',
#   'animal',
#   10.0,
#   0.01,
#   1.15,
#   3840267.2),
#  (7, 'Angola', 2013, 2740, 'Beurre, Ghee', 'animal', 2.0, 0.0, 0.19, 705355.2),
#  (7,
#   'Angola',
#   2013,
#   2744,
#   'Oeufs',
#   'animal',
#   4.0,
#   0.33,
#   0.29,
#   8699380.800000003),
#  (7, 'Angola', 2013, 2745, 'Miel', 'vegetal', 9.0, 0.01, None, 8542635.2),
#  (7,
#   'Angola',
#   2013,
#   2761,
#   'Poissons Eau Douce',
#   'animal',
#   2.0,
#   0.27,
#   0.06,
#   7210297.6),
#  (7, 'Angola', 2013, 2762, 'Perciform', 'animal', 7.0, 1.44, 0.13, 47964153.6),
#  (7,
#   'Angola',
#   2013,
#   2763,
#   'Poissons Pelagiques',
#   'animal',
#   14.0,
#   1.94,
#   0.59,
#   55331196.8),
#  (7,
#   'Angola',
#   2013,
#   2764,
#   'Poissons Marins, Autres',
#   'animal',
#   2.0,
#   0.33,
#   0.07,
#   8934499.199999997),
#  (7, 'Angola', 2013, 2765, 'Crustacés', 'animal', 0.0, 0.01, 0.0, 313491.2),
#  (7, 'Angola', 2013, 2766, 'Cephalopodes', 'animal', 0.0, 0.02, 0.0, 470236.8),
#  (7, 'Angola', 2013, 2767, 'Mollusques, Autres', 'animal', 0.0, 0.0, 0.0, 0.0),
#  (7,
#   'Angola',
#   2013,
#   2769,
#   'Animaux Aquatiques Autre',
#   'animal',
#   0.0,
#   0.0,
#   0.0,
#   0.0),
#  (7, 'Angola', 2013, 2775, 'Plantes Aquatiques', 'animal', 0.0, 0.0, 0.0, 0.0),
#  (7, 'Angola', 2013, 2781, 'Huiles de Poissons', 'animal', 0.0, 0.0, 0.0, 0.0),
#  (7,
#   'Angola',
#   2013,
#   2805,
#   'Riz (Eq Blanchi)',
#   'vegetal',
#   82.0,
#   1.56,
#   0.12,
#   63638713.6),
#  (7,
#   'Angola',
#   2013,
#   2848,
#   'Lait - Excl Beurre',
#   'animal',
#   20.0,
#   1.05,
#   1.09,
#   96398544.0),
#  (7, 'Angola', 2013, 2899, 'Miscellanees', 'vegetal', 3.0, 0.08, 0.03, None),
#  (8,
#   'Antigua-et-Barbuda',
#   2013,
#   2511,
#   'Blé',
#   'vegetal',
#   498.0,
#   13.49,
#   4.84,
#   2038671.0),
#  (8,
#   'Antigua-et-Barbuda',
#   2013,
#   2513,
#   'Orge',
#   'vegetal',
#   0.0,
#   None,
#   None,
#   None),
#  (8,
#   'Antigua-et-Barbuda',
#   2013,
#   2514,
#   'Maïs',
#   'vegetal',
#   22.0,
#   0.49,
#   0.24,
#   80154.0),
#  (8,
#   'Antigua-et-Barbuda',
#   2013,
#   2515,
#   'Seigle',
#   'vegetal',
#   0.0,
#   None,
#   None,
#   328.5),
#  (8,
#   'Antigua-et-Barbuda',
#   2013,
#   2516,
#   'Avoine',
#   'vegetal',
#   15.0,
#   0.64,
#   0.24,
#   87709.5),
#  (8,
#   'Antigua-et-Barbuda',
#   2013,
#   2517,
#   'Millet',
#   'vegetal',
#   0.0,
#   None,
#   None,
#   None),
#  (8,
#   'Antigua-et-Barbuda',
#   2013,
#   2518,
#   'Sorgho',
#   'vegetal',
#   0.0,
#   None,
#   None,
#   None),
#  (8,
#   'Antigua-et-Barbuda',
#   2013,
#   2520,
#   'Céréales, Autres',
#   'vegetal',
#   6.0,
#   0.15,
#   0.03,
#   33178.5),
#  (8,
#   'Antigua-et-Barbuda',
#   2013,
#   2531,
#   'Pommes de Terre',
#   'vegetal',
#   25.0,
#   0.58,
#   0.03,
#   513445.5),
#  (8,
#   'Antigua-et-Barbuda',
#   2013,
#   2532,
#   'Manioc',
#   'vegetal',
#   4.0,
#   0.03,
#   None,
#   45989.99999999999),
#  (8,
#   'Antigua-et-Barbuda',
#   2013,
#   2533,
#   'Patates douces',
#   'vegetal',
#   8.0,
#   0.09,
#   0.03,
#   104463.0),
#  (8,
#   'Antigua-et-Barbuda',
#   2013,
#   2534,
#   'Racines nda',
#   'vegetal',
#   4.0,
#   0.09,
#   None,
#   59130.0),
#  (8,
#   'Antigua-et-Barbuda',
#   2013,
#   2535,
#   'Ignames',
#   'vegetal',
#   3.0,
#   0.06,
#   None,
#   45332.99999999999),
#  (8,
#   'Antigua-et-Barbuda',
#   2013,
#   2542,
#   'Sucre Eq Brut',
#   'vegetal',
#   278.0,
#   None,
#   None,
#   913887.0),
#  (8,
#   'Antigua-et-Barbuda',
#   2013,
#   2543,
#   'Edulcorants Autres',
#   'vegetal',
#   21.0,
#   None,
#   None,
#   153081.0),
#  (8,
#   'Antigua-et-Barbuda',
#   2013,
#   2546,
#   'Haricots',
#   'vegetal',
#   14.0,
#   0.88,
#   0.06,
#   48618.0),
#  (8,
#   'Antigua-et-Barbuda',
#   2013,
#   2547,
#   'Pois',
#   'vegetal',
#   6.0,
#   0.4,
#   None,
#   20695.5),
#  (8,
#   'Antigua-et-Barbuda',
#   2013,
#   2549,
#   'Légumineuses Autres',
#   'vegetal',
#   8.0,
#   0.55,
#   0.06,
#   27594.0),
#  (8,
#   'Antigua-et-Barbuda',
#   2013,
#   2551,
#   'Noix',
#   'vegetal',
#   5.0,
#   0.12,
#   0.43,
#   22666.5),
#  (8,
#   'Antigua-et-Barbuda',
#   2013,
#   2555,
#   'Soja',
#   'vegetal',
#   0.0,
#   0.03,
#   0.0,
#   2299.5000000000005),
#  (8,
#   'Antigua-et-Barbuda',
#   2013,
#   2556,
#   'Arachides Decortiquees',
#   'vegetal',
#   14.0,
#   0.64,
#   1.16,
#   27922.5),
#  (8,
#   'Antigua-et-Barbuda',
#   2013,
#   2557,
#   'Graines de tournesol',
#   'vegetal',
#   0.0,
#   None,
#   None,
#   1314.0),
#  (8,
#   'Antigua-et-Barbuda',
#   2013,
#   2558,
#   'Graines Colza/Moutarde',
#   'vegetal',
#   3.0,
#   0.0,
#   0.0,
#   0.0),
#  (8,
#   'Antigua-et-Barbuda',
#   2013,
#   2560,
#   'Coco (Incl Coprah)',
#   'vegetal',
#   4.0,
#   0.03,
#   0.4,
#   28251.0),
#  (8,
#   'Antigua-et-Barbuda',
#   2013,
#   2561,
#   'Sésame',
#   'vegetal',
#   0.0,
#   None,
#   None,
#   328.5),
#  (8,
#   'Antigua-et-Barbuda',
#   2013,
#   2563,
#   'Olives',
#   'vegetal',
#   1.0,
#   None,
#   0.09,
#   11169.000000000002),
#  (8,
#   'Antigua-et-Barbuda',
#   2013,
#   2570,
#   'Plantes Oleiferes, Autre',
#   'vegetal',
#   1.0,
#   0.03,
#   0.03,
#   2299.5000000000005),
#  (8,
#   'Antigua-et-Barbuda',
#   2013,
#   2571,
#   'Huile de Soja',
#   'vegetal',
#   96.0,
#   None,
#   10.87,
#   130414.5),
#  (8,
#   'Antigua-et-Barbuda',
#   2013,
#   2572,
#   "Huile d'Arachide",
#   'vegetal',
#   2.0,
#   None,
#   0.21,
#   2628.0),
#  (8,
#   'Antigua-et-Barbuda',
#   2013,
#   2573,
#   'Huile de Tournesol',
#   'vegetal',
#   1.0,
#   None,
#   0.06,
#   657.0),
#  (8,
#   'Antigua-et-Barbuda',
#   2013,
#   2574,
#   'Huile de Colza&Moutarde',
#   'vegetal',
#   11.0,
#   None,
#   1.28,
#   15439.5),
#  (8,
#   'Antigua-et-Barbuda',
#   2013,
#   2575,
#   'Huile Graines de Coton',
#   'vegetal',
#   2.0,
#   None,
#   0.21,
#   2628.0),
#  (8,
#   'Antigua-et-Barbuda',
#   2013,
#   2577,
#   'Huile de Palme',
#   'vegetal',
#   None,
#   None,
#   None,
#   3613.5),
#  (8,
#   'Antigua-et-Barbuda',
#   2013,
#   2578,
#   'Huile de Coco',
#   'vegetal',
#   1.0,
#   None,
#   0.12,
#   1314.0),
#  (8,
#   'Antigua-et-Barbuda',
#   2013,
#   2579,
#   'Huile de Sésame',
#   'vegetal',
#   1.0,
#   None,
#   0.09,
#   985.5),
#  (8,
#   'Antigua-et-Barbuda',
#   2013,
#   2580,
#   "Huile d'Olive",
#   'vegetal',
#   12.0,
#   None,
#   1.4,
#   16753.5),
#  (8,
#   'Antigua-et-Barbuda',
#   2013,
#   2582,
#   'Huile de Germe de Maïs',
#   'vegetal',
#   4.0,
#   None,
#   0.49,
#   5913.0),
#  (8,
#   'Antigua-et-Barbuda',
#   2013,
#   2586,
#   'Huil Plantes Oleif Autr',
#   'vegetal',
#   87.0,
#   0.09,
#   9.83,
#   121216.5),
#  (8,
#   'Antigua-et-Barbuda',
#   2013,
#   2601,
#   'Tomates',
#   'vegetal',
#   7.0,
#   0.3,
#   0.09,
#   394200.0),
#  (8,
#   'Antigua-et-Barbuda',
#   2013,
#   2602,
#   'Oignons',
#   'vegetal',
#   7.0,
#   0.21,
#   0.03,
#   195129.0),
#  (8,
#   'Antigua-et-Barbuda',
#   2013,
#   2605,
#   'Légumes, Autres',
#   'vegetal',
#   46.0,
#   1.95,
#   0.27,
#   1852083.0),
#  (8,
#   'Antigua-et-Barbuda',
#   2013,
#   2611,
#   'Oranges, Mandarines',
#   'vegetal',
#   7.0,
#   0.12,
#   0.0,
#   575532.0),
#  (8,
#   'Antigua-et-Barbuda',
#   2013,
#   2612,
#   'Citrons & Limes',
#   'vegetal',
#   2.0,
#   0.06,
#   0.03,
#   148810.5),
#  (8,
#   'Antigua-et-Barbuda',
#   2013,
#   2613,
#   'Pamplemousse',
#   'vegetal',
#   1.0,
#   None,
#   None,
#   91651.5),
#  (8,
#   'Antigua-et-Barbuda',
#   2013,
#   2614,
#   'Agrumes, Autres',
#   'vegetal',
#   1.0,
#   None,
#   None,
#   43033.5),
#  (8,
#   'Antigua-et-Barbuda',
#   2013,
#   2615,
#   'Bananes',
#   'vegetal',
#   19.0,
#   0.21,
#   0.09,
#   375147.0),
#  (8,
#   'Antigua-et-Barbuda',
#   2013,
#   2616,
#   'Bananes plantains',
#   'vegetal',
#   5.0,
#   0.06,
#   None,
#   81468.0),
#  (8,
#   'Antigua-et-Barbuda',
#   2013,
#   2617,
#   'Pommes',
#   'vegetal',
#   1.0,
#   None,
#   None,
#   67999.5),
#  (8,
#   'Antigua-et-Barbuda',
#   2013,
#   2618,
#   'Ananas',
#   'vegetal',
#   8.0,
#   0.06,
#   None,
#   255901.5),
#  (8,
#   'Antigua-et-Barbuda',
#   2013,
#   2619,
#   'Dattes',
#   'vegetal',
#   0.0,
#   None,
#   None,
#   2956.5),
#  (8,
#   'Antigua-et-Barbuda',
#   2013,
#   2620,
#   'Raisin',
#   'vegetal',
#   8.0,
#   0.09,
#   None,
#   138627.0),
#  (8,
#   'Antigua-et-Barbuda',
#   2013,
#   2625,
#   'Fruits, Autres',
#   'vegetal',
#   116.0,
#   1.25,
#   1.92,
#   3401946.0),
#  (8,
#   'Antigua-et-Barbuda',
#   2013,
#   2630,
#   'Café',
#   'vegetal',
#   3.0,
#   0.18,
#   None,
#   66685.49999999999),
#  (8,
#   'Antigua-et-Barbuda',
#   2013,
#   2633,
#   'Feve de Cacao',
#   'vegetal',
#   19.0,
#   0.21,
#   1.67,
#   32850.0),
#  (8,
#   'Antigua-et-Barbuda',
#   2013,
#   2635,
#   'Thé',
#   'vegetal',
#   1.0,
#   0.24,
#   None,
#   29565.0),
#  (8,
#   'Antigua-et-Barbuda',
#   2013,
#   2640,
#   'Poivre',
#   'vegetal',
#   3.0,
#   0.12,
#   None,
#   13140.0),
#  (8,
#   'Antigua-et-Barbuda',
#   2013,
#   2641,
#   'Piments',
#   'vegetal',
#   2.0,
#   None,
#   0.09,
#   5913.0),
#  (8,
#   'Antigua-et-Barbuda',
#   2013,
#   2642,
#   'Girofles',
#   'vegetal',
#   0.0,
#   None,
#   None,
#   1314.0),
#  (8,
#   'Antigua-et-Barbuda',
#   2013,
#   2645,
#   'Épices, Autres',
#   'vegetal',
#   10.0,
#   0.27,
#   0.37,
#   33835.5),
#  (8,
#   'Antigua-et-Barbuda',
#   2013,
#   2655,
#   'Vin',
#   'vegetal',
#   23.0,
#   None,
#   None,
#   311746.5),
#  (8,
#   'Antigua-et-Barbuda',
#   2013,
#   2656,
#   'Bière',
#   'vegetal',
#   17.0,
#   0.15,
#   None,
#   567648.0),
#  (8,
#   'Antigua-et-Barbuda',
#   2013,
#   2657,
#   'Boissons Fermentés',
#   'vegetal',
#   1.0,
#   None,
#   None,
#   26280.0),
#  (8,
#   'Antigua-et-Barbuda',
#   2013,
#   2658,
#   'Boissons Alcooliques',
#   'vegetal',
#   43.0,
#   None,
#   None,
#   175090.5),
#  (8,
#   'Antigua-et-Barbuda',
#   2013,
#   2680,
#   'Aliments pour enfants',
#   'vegetal',
#   6.0,
#   0.24,
#   0.03,
#   18396.000000000004),
#  (8,
#   'Antigua-et-Barbuda',
#   2013,
#   2731,
#   'Viande de Bovins',
#   'animal',
#   56.0,
#   5.66,
#   3.53,
#   407997.0),
#  (8,
#   'Antigua-et-Barbuda',
#   2013,
#   2732,
#   "Viande d'Ovins/Caprins",
#   'animal',
#   7.0,
#   0.61,
#   0.52,
#   53545.5),
#  (8,
#   'Antigua-et-Barbuda',
#   2013,
#   2733,
#   'Viande de Suides',
#   'animal',
#   61.0,
#   3.35,
#   5.08,
#   375804.0),
#  (8,
#   'Antigua-et-Barbuda',
#   2013,
#   2734,
#   'Viande de Volailles',
#   'animal',
#   251.0,
#   19.0,
#   18.93,
#   1932237.0),
#  (8,
#   'Antigua-et-Barbuda',
#   2013,
#   2735,
#   'Viande, Autre',
#   'animal',
#   3.0,
#   0.46,
#   0.09,
#   24309.0),
#  (8,
#   'Antigua-et-Barbuda',
#   2013,
#   2736,
#   'Abats Comestible',
#   'animal',
#   8.0,
#   1.37,
#   0.18,
#   90009.00000000001),
#  (8,
#   'Antigua-et-Barbuda',
#   2013,
#   2737,
#   'Graisses Animales Crue',
#   'animal',
#   33.0,
#   0.03,
#   3.68,
#   53545.5),
#  (8,
#   'Antigua-et-Barbuda',
#   2013,
#   2740,
#   'Beurre, Ghee',
#   'animal',
#   35.0,
#   0.03,
#   3.93,
#   57816.0),
#  (8,
#   'Antigua-et-Barbuda',
#   2013,
#   2743,
#   'Crème',
#   'animal',
#   8.0,
#   0.09,
#   0.76,
#   46318.5),
#  (8,
#   'Antigua-et-Barbuda',
#   2013,
#   2744,
#   'Oeufs',
#   'animal',
#   15.0,
#   1.19,
#   1.0,
#   142240.5),
#  (8,
#   'Antigua-et-Barbuda',
#   2013,
#   2745,
#   'Miel',
#   'vegetal',
#   3.0,
#   None,
#   None,
#   13797.0),
#  (8,
#   'Antigua-et-Barbuda',
#   2013,
#   2761,
#   'Poissons Eau Douce',
#   'animal',
#   2.0,
#   0.23,
#   0.07,
#   24309.0),
#  (8,
#   'Antigua-et-Barbuda',
#   2013,
#   2762,
#   'Perciform',
#   'animal',
#   10.0,
#   1.99,
#   0.18,
#   276925.5),
#  (8,
#   'Antigua-et-Barbuda',
#   2013,
#   2763,
#   'Poissons Pelagiques',
#   'animal',
#   22.0,
#   2.72,
#   1.14,
#   304191.0),
#  (8,
#   'Antigua-et-Barbuda',
#   2013,
#   2764,
#   'Poissons Marins, Autres',
#   'animal',
#   33.0,
#   5.76,
#   0.86,
#   591957.0),
#  (8,
#   'Antigua-et-Barbuda',
#   2013,
#   2765,
#   'Crustacés',
#   'animal',
#   7.0,
#   1.44,
#   0.07,
#   205641.0),
#  (8,
#   'Antigua-et-Barbuda',
#   2013,
#   2766,
#   'Cephalopodes',
#   'animal',
#   1.0,
#   0.12,
#   0.01,
#   9855.0),
#  (8,
#   'Antigua-et-Barbuda',
#   2013,
#   2767,
#   'Mollusques, Autres',
#   'animal',
#   5.0,
#   0.69,
#   0.06,
#   340326.0),
#  (8,
#   'Antigua-et-Barbuda',
#   2013,
#   2775,
#   'Plantes Aquatiques',
#   'animal',
#   0.0,
#   0.0,
#   0.0,
#   0.0),
#  (8,
#   'Antigua-et-Barbuda',
#   2013,
#   2781,
#   'Huiles de Poissons',
#   'animal',
#   0.0,
#   0.0,
#   0.0,
#   0.0),
#  (8,
#   'Antigua-et-Barbuda',
#   2013,
#   2782,
#   'Huiles de Foie de Poisso',
#   'animal',
#   0.0,
#   0.0,
#   0.0,
#   0.0),
#  (8,
#   'Antigua-et-Barbuda',
#   2013,
#   2805,
#   'Riz (Eq Blanchi)',
#   'vegetal',
#   110.0,
#   2.28,
#   0.52,
#   310761.00000000006),
#  (8,
#   'Antigua-et-Barbuda',
#   2013,
#   2848,
#   'Lait - Excl Beurre',
#   'animal',
#   224.0,
#   12.09,
#   12.12,
#   4064859.0),
#  (8,
#   'Antigua-et-Barbuda',
#   2013,
#   2899,
#   'Miscellanees',
#   'vegetal',
#   9.0,
#   0.27,
#   0.24,
#   None),
#  (9,
#   'Argentine',
#   2013,
#   2511,
#   'Blé',
#   'vegetal',
#   877.0,
#   23.37,
#   2.42,
#   1559826426.9),
#  (9, 'Argentine', 2013, 2513, 'Orge', 'vegetal', 0.0, 0.0, 0.0, 0.0),
#  (9,
#   'Argentine',
#   2013,
#   2514,
#   'Maïs',
#   'vegetal',
#   86.0,
#   1.96,
#   0.27,
#   157934127.6),
#  (9, 'Argentine', 2013, 2515, 'Seigle', 'vegetal', 0.0, 0.0, 0.0, 0.0),
#  (9, 'Argentine', 2013, 2516, 'Avoine', 'vegetal', 4.0, 0.15, 0.06, 9681785.6),
#  (9,
#   'Argentine',
#   2013,
#   2520,
#   'Céréales, Autres',
#   'vegetal',
#   3.0,
#   0.09,
#   0.01,
#   7110061.3),
#  (9,
#   'Argentine',
#   2013,
#   2531,
#   'Pommes de Terre',
#   'vegetal',
#   60.0,
#   2.13,
#   0.18,
#   496947901.5),
#  (9,
#   'Argentine',
#   2013,
#   2532,
#   'Manioc',
#   'vegetal',
#   5.0,
#   0.03,
#   0.01,
#   28591523.1),
#  (9,
#   'Argentine',
#   2013,
#   2533,
#   'Patates douces',
#   'vegetal',
#   21.0,
#   0.25,
#   0.05,
#   135998832.1),
#  (9,
#   'Argentine',
#   2013,
#   2542,
#   'Sucre Eq Brut',
#   'vegetal',
#   403.0,
#   None,
#   None,
#   626895617.6),
#  (9,
#   'Argentine',
#   2013,
#   2543,
#   'Edulcorants Autres',
#   'vegetal',
#   66.0,
#   0.01,
#   None,
#   101810026.7),
#  (9,
#   'Argentine',
#   2013,
#   2546,
#   'Haricots',
#   'vegetal',
#   2.0,
#   0.13,
#   0.01,
#   3328113.8),
#  (9,
#   'Argentine',
#   2013,
#   2547,
#   'Pois',
#   'vegetal',
#   2.0,
#   0.1,
#   0.01,
#   2571724.3000000003),
#  (9,
#   'Argentine',
#   2013,
#   2549,
#   'Légumineuses Autres',
#   'vegetal',
#   4.0,
#   0.29,
#   0.04,
#   6958783.4),
#  (9, 'Argentine', 2013, 2551, 'Noix', 'vegetal', 3.0, 0.08, 0.31, 6656227.6),
#  (9, 'Argentine', 2013, 2555, 'Soja', 'vegetal', 0.0, 0.0, 0.0, 0.0),
#  (9,
#   'Argentine',
#   2013,
#   2556,
#   'Arachides Decortiquees',
#   'vegetal',
#   1.0,
#   0.04,
#   0.07,
#   756389.5),
#  (9,
#   'Argentine',
#   2013,
#   2558,
#   'Graines Colza/Moutarde',
#   'vegetal',
#   0.0,
#   None,
#   None,
#   0.0),
#  (9,
#   'Argentine',
#   2013,
#   2560,
#   'Coco (Incl Coprah)',
#   'vegetal',
#   1.0,
#   0.01,
#   0.08,
#   3630669.6),
#  (9, 'Argentine', 2013, 2561, 'Sésame', 'vegetal', 0.0, 0.01, 0.04, 453833.7),
#  (9, 'Argentine', 2013, 2563, 'Olives', 'vegetal', 0.0, 0.0, 0.04, 1664056.9),
#  (9,
#   'Argentine',
#   2013,
#   2570,
# ...
#  (14, 'Barbade', 2013, 2619, 'Dattes', 'vegetal', 0.0, None, None, 5201.25),
#  (14, 'Barbade', 2013, 2620, 'Raisin', 'vegetal', 14.0, 0.12, 0.09, 812435.25),
#  (14,
#   'Barbade',
#   2013,
#   2625,
#   'Fruits, Autres',
#   'vegetal',
#   30.0,
#   0.39,
#   0.52,
#   2469553.5),
#  (14, 'Barbade', 2013, 2630, 'Café', 'vegetal', 3.0, 0.18, None, 265263.75),
#  (14,
#   'Barbade',
#   2013,
#   2633,
#   'Feve de Cacao',
#   'vegetal',
#   13.0,
#   0.2,
#   1.19,
#   93622.5),
#  (14, 'Barbade', 2013, 2635, 'Thé', 'vegetal', 1.0, 0.25, None, 97783.5),
#  (14, 'Barbade', 2013, 2640, 'Poivre', 'vegetal', 3.0, 0.11, 0.03, 38489.25),
#  (14, 'Barbade', 2013, 2641, 'Piments', 'vegetal', 2.0, 0.06, 0.09, 19764.75),
#  (14,
#   'Barbade',
#   2013,
#   2642,
#   'Girofles',
#   'vegetal',
#   1.0,
#   0.01,
#   0.04,
#   7281.750000000001),
#  (14,
#   'Barbade',
#   2013,
#   2645,
#   'Épices, Autres',
#   'vegetal',
#   8.0,
#   0.24,
#   0.31,
#   89461.5),
#  (14, 'Barbade', 2013, 2655, 'Vin', 'vegetal', 17.0, None, None, 879011.25),
#  (14, 'Barbade', 2013, 2656, 'Bière', 'vegetal', 50.0, 0.42, None, 5322959.25),
#  (14,
#   'Barbade',
#   2013,
#   2657,
#   'Boissons Fermentés',
#   'vegetal',
#   0.0,
#   None,
#   None,
#   11442.75),
#  (14,
#   'Barbade',
#   2013,
#   2658,
#   'Boissons Alcooliques',
#   'vegetal',
#   19.0,
#   None,
#   None,
#   243418.5),
#  (14,
#   'Barbade',
#   2013,
#   2680,
#   'Aliments pour enfants',
#   'vegetal',
#   14.0,
#   0.58,
#   0.11,
#   144594.75),
#  (14,
#   'Barbade',
#   2013,
#   2731,
#   'Viande de Bovins',
#   'animal',
#   60.0,
#   7.0,
#   3.31,
#   1365848.25),
#  (14,
#   'Barbade',
#   2013,
#   2732,
#   "Viande d'Ovins/Caprins",
#   'animal',
#   24.0,
#   1.5,
#   1.9,
#   424422.0),
#  (14,
#   'Barbade',
#   2013,
#   2733,
#   'Viande de Suides',
#   'animal',
#   50.0,
#   1.72,
#   4.45,
#   863407.5),
#  (14,
#   'Barbade',
#   2013,
#   2734,
#   'Viande de Volailles',
#   'animal',
#   180.0,
#   14.19,
#   13.3,
#   4433545.5),
#  (14, 'Barbade', 2013, 2735, 'Viande, Autre', 'animal', 0.0, 0.0, 0.0, 0.0),
#  (14,
#   'Barbade',
#   2013,
#   2736,
#   'Abats Comestible',
#   'animal',
#   7.0,
#   1.1,
#   0.2,
#   229895.25),
#  (14,
#   'Barbade',
#   2013,
#   2737,
#   'Graisses Animales Crue',
#   'animal',
#   38.0,
#   0.01,
#   4.18,
#   228855.0),
#  (14,
#   'Barbade',
#   2013,
#   2740,
#   'Beurre, Ghee',
#   'animal',
#   15.0,
#   0.02,
#   1.67,
#   78018.75),
#  (14, 'Barbade', 2013, 2743, 'Crème', 'animal', 13.0, 0.17, 1.27, 249660.0),
#  (14, 'Barbade', 2013, 2744, 'Oeufs', 'animal', 34.0, 2.61, 2.27, 999680.25),
#  (14, 'Barbade', 2013, 2745, 'Miel', 'vegetal', 3.0, None, None, 34328.25),
#  (14,
#   'Barbade',
#   2013,
#   2761,
#   'Poissons Eau Douce',
#   'animal',
#   2.0,
#   0.24,
#   0.08,
#   76978.5),
#  (14, 'Barbade', 2013, 2762, 'Perciform', 'animal', 4.0, 0.88, 0.05, 280867.5),
#  (14,
#   'Barbade',
#   2013,
#   2763,
#   'Poissons Pelagiques',
#   'animal',
#   56.0,
#   7.33,
#   2.7,
#   2442507.0),
#  (14,
#   'Barbade',
#   2013,
#   2764,
#   'Poissons Marins, Autres',
#   'animal',
#   17.0,
#   2.95,
#   0.51,
#   1091222.25),
#  (14, 'Barbade', 2013, 2765, 'Crustacés', 'animal', 2.0, 0.42, 0.02, 191406.0),
#  (14,
#   'Barbade',
#   2013,
#   2766,
#   'Cephalopodes',
#   'animal',
#   1.0,
#   0.13,
#   0.01,
#   33288.0),
#  (14,
#   'Barbade',
#   2013,
#   2767,
#   'Mollusques, Autres',
#   'animal',
#   0.0,
#   0.04,
#   0.01,
#   59294.25),
#  (14,
#   'Barbade',
#   2013,
#   2775,
#   'Plantes Aquatiques',
#   'animal',
#   0.0,
#   0.0,
#   0.0,
#   0.0),
#  (14,
#   'Barbade',
#   2013,
#   2781,
#   'Huiles de Poissons',
#   'animal',
#   0.0,
#   0.0,
#   0.0,
#   0.0),
#  (14,
#   'Barbade',
#   2013,
#   2782,
#   'Huiles de Foie de Poisso',
#   'animal',
#   0.0,
#   0.0,
#   0.0,
#   0.0),
#  (14,
#   'Barbade',
#   2013,
#   2805,
#   'Riz (Eq Blanchi)',
#   'vegetal',
#   170.0,
#   3.48,
#   0.6,
#   1629031.5),
#  (14,
#   'Barbade',
#   2013,
#   2848,
#   'Lait - Excl Beurre',
#   'animal',
#   185.0,
#   10.21,
#   10.11,
#   11492682.0),
#  (14,
#   'Barbade',
#   2013,
#   2899,
#   'Miscellanees',
#   'vegetal',
#   44.0,
#   1.29,
#   0.54,
#   None),
#  (16,
#   'Bangladesh',
#   2013,
#   2511,
#   'Blé',
#   'vegetal',
#   150.0,
#   4.36,
#   0.7,
#   998535847.25),
#  (16, 'Bangladesh', 2013, 2513, 'Orge', 'vegetal', 0.0, 0.0, 0.0, 0.0),
#  (16,
#   'Bangladesh',
#   2013,
#   2514,
#   'Maïs',
#   'vegetal',
#   8.0,
#   0.21,
#   0.09,
#   45725740.0),
#  (16, 'Bangladesh', 2013, 2516, 'Avoine', 'vegetal', 0.0, 0.0, 0.0, 0.0),
#  (16,
#   'Bangladesh',
#   2013,
#   2517,
#   'Millet',
#   'vegetal',
#   1.0,
#   0.02,
#   0.01,
#   4572574.0),
#  (16, 'Bangladesh', 2013, 2518, 'Sorgho', 'vegetal', 0.0, 0.0, 0.0, 0.0),
#  (16,
#   'Bangladesh',
#   2013,
#   2520,
#   'Céréales, Autres',
#   'vegetal',
#   0.0,
#   0.0,
#   0.0,
#   0.0),
#  (16,
#   'Bangladesh',
#   2013,
#   2531,
#   'Pommes de Terre',
#   'vegetal',
#   90.0,
#   2.19,
#   0.13,
#   2652092920.0),
#  (16,
#   'Bangladesh',
#   2013,
#   2532,
#   'Manioc',
#   'vegetal',
#   0.0,
#   0.0,
#   0.0,
#   8573576.25),
#  (16,
#   'Bangladesh',
#   2013,
#   2533,
#   'Patates douces',
#   'vegetal',
#   4.0,
#   0.04,
#   0.01,
#   85164190.75),
#  (16, 'Bangladesh', 2013, 2534, 'Racines nda', 'vegetal', 0.0, 0.0, 0.0, 0.0),
#  (16,
#   'Bangladesh',
#   2013,
#   2536,
#   'Sucre, canne',
#   'vegetal',
#   2.0,
#   0.01,
#   0.01,
#   109741776.0),
#  (16,
#   'Bangladesh',
#   2013,
#   2541,
#   'Sucre non centrifugé',
#   'vegetal',
#   16.0,
#   0.05,
#   None,
#   97167197.5),
#  (16,
#   'Bangladesh',
#   2013,
#   2542,
#   'Sucre Eq Brut',
#   'vegetal',
#   53.0,
#   None,
#   None,
#   311506603.75),
#  (16,
#   'Bangladesh',
#   2013,
#   2543,
#   'Edulcorants Autres',
#   'vegetal',
#   6.0,
#   None,
#   None,
#   52584601.0),
#  (16,
#   'Bangladesh',
#   2013,
#   2546,
#   'Haricots',
#   'vegetal',
#   3.0,
#   0.18,
#   0.01,
#   17147152.5),
#  (16,
#   'Bangladesh',
#   2013,
#   2547,
#   'Pois',
#   'vegetal',
#   24.0,
#   1.59,
#   0.13,
#   147465511.5),
#  (16,
#   'Bangladesh',
#   2013,
#   2549,
#   'Légumineuses Autres',
#   'vegetal',
#   35.0,
#   2.05,
#   0.26,
#   210909975.75),
#  (16,
#   'Bangladesh',
#   2013,
#   2551,
#   'Noix',
#   'vegetal',
#   5.0,
#   0.1,
#   0.11,
#   39438450.74999999),
#  (16,
#   'Bangladesh',
#   2013,
#   2555,
#   'Soja',
#   'vegetal',
#   6.0,
#   0.63,
#   0.3,
#   34865876.75),
#  (16,
#   'Bangladesh',
#   2013,
#   2556,
#   'Arachides Decortiquees',
#   'vegetal',
#   0.0,
#   0.02,
#   0.04,
#   1714715.25),
#  (16,
#   'Bangladesh',
#   2013,
#   2557,
#   'Graines de tournesol',
#   'vegetal',
#   0.0,
#   0.0,
#   0.0,
#   0.0),
#  (16,
#   'Bangladesh',
#   2013,
#   2558,
#   'Graines Colza/Moutarde',
#   'vegetal',
#   0.0,
#   0.0,
#   0.0,
#   0.0),
#  (16,
#   'Bangladesh',
#   2013,
#   2560,
#   'Coco (Incl Coprah)',
#   'vegetal',
#   0.0,
#   0.0,
#   0.01,
#   2286287.0),
#  (16, 'Bangladesh', 2013, 2563, 'Olives', 'vegetal', 0.0, None, 0.0, 0.0),
#  (16,
#   'Bangladesh',
#   2013,
#   2570,
#   'Plantes Oleiferes, Autre',
#   'vegetal',
#   0.0,
#   0.0,
#   0.0,
#   0.0),
#  (16,
#   'Bangladesh',
#   2013,
#   2571,
#   'Huile de Soja',
#   'vegetal',
#   45.0,
#   None,
#   5.04,
#   105169202.0),
#  (16,
#   'Bangladesh',
#   2013,
#   2572,
#   "Huile d'Arachide",
#   'vegetal',
#   2.0,
#   None,
#   0.22,
#   4572574.0),
#  (16,
#   'Bangladesh',
#   2013,
#   2573,
#   'Huile de Tournesol',
#   'vegetal',
#   0.0,
#   None,
#   0.01,
#   0.0),
#  (16,
#   'Bangladesh',
#   2013,
#   2574,
#   'Huile de Colza&Moutarde',
#   'vegetal',
#   16.0,
#   None,
#   1.83,
#   38295307.25),
#  (16,
#   'Bangladesh',
#   2013,
#   2575,
#   'Huile Graines de Coton',
#   'vegetal',
#   1.0,
#   None,
#   0.08,
#   1714715.25),
#  (16,
#   'Bangladesh',
#   2013,
#   2577,
#   'Huile de Palme',
#   'vegetal',
#   85.0,
#   None,
#   9.62,
#   200621684.25),
#  (16,
#   'Bangladesh',
#   2013,
#   2578,
#   'Huile de Coco',
#   'vegetal',
#   3.0,
#   None,
#   0.39,
#   8002004.500000001),
#  (16,
#   'Bangladesh',
#   2013,
#   2579,
#   'Huile de Sésame',
#   'vegetal',
#   1.0,
#   None,
#   0.09,
#   1714715.25),
#  (16,
#   'Bangladesh',
#   2013,
#   2580,
#   "Huile d'Olive",
#   'vegetal',
#   0.0,
#   None,
#   0.0,
#   0.0),
#  (16,
#   'Bangladesh',
#   2013,
#   2581,
#   'Huile de Son de Riz',
#   'vegetal',
#   0.0,
#   None,
#   0.05,
#   1143143.5),
#  (16,
#   'Bangladesh',
#   2013,
#   2582,
#   'Huile de Germe de Maïs',
#   'vegetal',
#   0.0,
#   None,
#   0.0,
#   0.0),
#  (16,
#   'Bangladesh',
#   2013,
#   2586,
#   'Huil Plantes Oleif Autr',
#   'vegetal',
#   0.0,
#   0.0,
#   0.03,
#   571571.75),
#  (16,
#   'Bangladesh',
#   2013,
#   2601,
#   'Tomates',
#   'vegetal',
#   1.0,
#   0.05,
#   0.01,
#   89736764.75),
#  (16,
#   'Bangladesh',
#   2013,
#   2602,
#   'Oignons',
#   'vegetal',
#   10.0,
#   0.38,
#   0.05,
#   529847012.25),
#  (16,
#   'Bangladesh',
#   2013,
#   2605,
#   'Légumes, Autres',
#   'vegetal',
#   14.0,
#   0.67,
#   0.1,
#   942521815.75),
#  (16,
#   'Bangladesh',
#   2013,
#   2611,
#   'Oranges, Mandarines',
#   'vegetal',
#   1.0,
#   0.01,
#   0.0,
#   44582596.5),
#  (16,
#   'Bangladesh',
#   2013,
#   2612,
#   'Citrons & Limes',
#   'vegetal',
#   0.0,
#   0.0,
#   0.01,
#   20576583.0),
#  (16,
#   'Bangladesh',
#   2013,
#   2613,
#   'Pamplemousse',
#   'vegetal',
#   0.0,
#   0.0,
#   0.0,
#   21148154.75),
#  (16,
#   'Bangladesh',
#   2013,
#   2614,
#   'Agrumes, Autres',
#   'vegetal',
#   0.0,
#   0.0,
#   0.0,
#   2857858.75),
#  (16,
#   'Bangladesh',
#   2013,
#   2615,
#   'Bananes',
#   'vegetal',
#   8.0,
#   0.1,
#   0.02,
#   254349428.75),
#  (16,
#   'Bangladesh',
#   2013,
#   2617,
#   'Pommes',
#   'vegetal',
#   1.0,
#   0.0,
#   0.01,
#   54299316.25),
#  (16,
#   'Bangladesh',
#   2013,
#   2618,
#   'Ananas',
#   'vegetal',
#   1.0,
#   0.01,
#   0.01,
#   61158177.25),
#  (16, 'Bangladesh', 2013, 2619, 'Dattes', 'vegetal', 0.0, 0.0, 0.0, 0.0),
#  (16,
#   'Bangladesh',
#   2013,
#   2620,
#   'Raisin',
#   'vegetal',
#   0.0,
#   0.0,
#   0.0,
#   14860865.5),
#  (16,
#   'Bangladesh',
#   2013,
#   2625,
#   'Fruits, Autres',
#   'vegetal',
#   18.0,
#   0.19,
#   0.2,
#   860215483.75),
#  (16, 'Bangladesh', 2013, 2630, 'Café', 'vegetal', 0.0, 0.0, None, 0.0),
#  (16,
#   'Bangladesh',
#   2013,
#   2633,
#   'Feve de Cacao',
#   'vegetal',
#   0.0,
#   0.0,
#   0.01,
#   571571.75),
#  (16, 'Bangladesh', 2013, 2635, 'Thé', 'vegetal', 1.0, 0.13, None, 27435444.0),
#  (16, 'Bangladesh', 2013, 2640, 'Poivre', 'vegetal', 0.0, 0.0, 0.0, 0.0),
#  (16,
#   'Bangladesh',
#   2013,
#   2641,
#   'Piments',
#   'vegetal',
#   6.0,
#   0.25,
#   0.26,
#   44011024.75),
#  (16, 'Bangladesh', 2013, 2642, 'Girofles', 'vegetal', 0.0, 0.0, 0.0, 0.0),
#  (16,
#   'Bangladesh',
#   2013,
#   2645,
#   'Épices, Autres',
#   'vegetal',
#   17.0,
#   0.54,
#   0.36,
#   111456491.25),
#  (16, 'Bangladesh', 2013, 2655, 'Vin', 'vegetal', 0.0, None, None, 0.0),
#  (16, 'Bangladesh', 2013, 2656, 'Bière', 'vegetal', 0.0, 0.0, None, 571571.75),
#  (16,
#   'Bangladesh',
#   2013,
#   2657,
#   'Boissons Fermentés',
#   'vegetal',
#   0.0,
#   None,
#   None,
#   0.0),
#  (16,
#   'Bangladesh',
#   2013,
#   2658,
#   'Boissons Alcooliques',
#   'vegetal',
#   0.0,
#   None,
#   None,
#   571571.75),
#  (16,
#   'Bangladesh',
#   2013,
#   2680,
#   'Aliments pour enfants',
#   'vegetal',
#   0.0,
#   0.01,
#   0.0,
#   1714715.25),
#  (16,
#   'Bangladesh',
#   2013,
#   2731,
#   'Viande de Bovins',
#   'animal',
#   6.0,
#   0.54,
#   0.41,
#   73161184.0),
#  (16,
#   'Bangladesh',
#   2013,
#   2732,
#   "Viande d'Ovins/Caprins",
#   'animal',
#   6.0,
#   0.56,
#   0.35,
#   76019042.75),
#  (16,
#   'Bangladesh',
#   2013,
#   2733,
#   'Viande de Suides',
#   'animal',
#   0.0,
#   0.0,
#   0.0,
#   0.0),
#  (16,
#   'Bangladesh',
#   2013,
#   2734,
#   'Viande de Volailles',
#   'animal',
#   6.0,
#   0.44,
#   0.46,
#   80020045.0),
#  (16,
#   'Bangladesh',
#   2013,
#   2735,
#   'Viande, Autre',
#   'animal',
#   0.0,
#   0.06,
#   0.0,
#   5715717.5),
#  (16,
#   'Bangladesh',
#   2013,
#   2736,
#   'Abats Comestible',
#   'animal',
#   2.0,
#   0.26,
#   0.07,
#   33722733.25),
#  (16,
#   'Bangladesh',
#   2013,
#   2737,
#   'Graisses Animales Crue',
#   'animal',
#   3.0,
#   0.01,
#   0.34,
#   7430432.75),
#  (16,
#   'Bangladesh',
#   2013,
#   2740,
#   'Beurre, Ghee',
#   'animal',
#   5.0,
#   0.0,
#   0.53,
#   11431435.0),
#  (16, 'Bangladesh', 2013, 2743, 'Crème', 'animal', 0.0, 0.0, 0.0, 0.0),
#  (16,
#   'Bangladesh',
#   2013,
#   2744,
#   'Oeufs',
#   'animal',
#   9.0,
#   0.64,
#   0.62,
#   118886924.0),
#  (16, 'Bangladesh', 2013, 2745, 'Miel', 'vegetal', 0.0, None, None, 0.0),
#  (16,
#   'Bangladesh',
#   2013,
#   2761,
#   'Poissons Eau Douce',
#   'animal',
#   29.0,
#   4.53,
#   1.04,
#   929375665.5),
#  (16,
#   'Bangladesh',
#   2013,
#   2762,
#   'Perciform',
#   'animal',
#   1.0,
#   0.17,
#   0.01,
#   34294305.0),
#  (16,
#   'Bangladesh',
#   2013,
#   2763,
#   'Poissons Pelagiques',
#   'animal',
#   1.0,
#   0.14,
#   0.03,
#   27435444.0),
#  (16,
#   'Bangladesh',
#   2013,
#   2764,
#   'Poissons Marins, Autres',
#   'animal',
#   1.0,
#   0.22,
#   0.04,
#   41724737.75),
#  (16,
#   'Bangladesh',
#   2013,
#   2765,
#   'Crustacés',
#   'animal',
#   2.0,
#   0.31,
#   0.02,
#   65159179.49999999),
#  (16, 'Bangladesh', 2013, 2766, 'Cephalopodes', 'animal', 0.0, 0.0, 0.0, 0.0),
#  (16,
#   'Bangladesh',
#   2013,
#   2767,
#   'Mollusques, Autres',
#   'animal',
#   0.0,
#   0.0,
#   0.0,
#   0.0),
#  (16,
#   'Bangladesh',
#   2013,
#   2769,
#   'Animaux Aquatiques Autre',
#   'animal',
#   0.0,
#   0.0,
#   0.0,
#   0.0),
#  (16,
#   'Bangladesh',
#   2013,
#   2775,
#   'Plantes Aquatiques',
#   'animal',
#   0.0,
#   0.0,
#   0.0,
#   0.0),
#  (16,
#   'Bangladesh',
#   2013,
#   2781,
#   'Huiles de Poissons',
#   'animal',
#   0.0,
#   0.0,
#   0.0,
#   0.0),
#  (16,
#   'Bangladesh',
#   2013,
#   2782,
#   'Huiles de Foie de Poisso',
#   'animal',
#   0.0,
#   0.0,
#   0.0,
#   0.0),
#  (16,
#   'Bangladesh',
#   2013,
#   2805,
#   'Riz (Eq Blanchi)',
#   'vegetal',
#   1711.0,
#   32.14,
#   3.78,
#   9815601662.75),
#  (16,
#   'Bangladesh',
#   2013,
#   2848,
#   'Lait - Excl Beurre',
#   'animal',
#   37.0,
#   2.05,
#   2.0,
#   1252313704.25),
#  (16,
#   'Bangladesh',
#   2013,
#   2899,
#   'Miscellanees',
#   'vegetal',
#   0.0,
#   0.0,
#   0.01,
#   None),
#  (17,
#   'Bermudes',
#   2013,
#   2511,
#   'Blé',
#   'vegetal',
#   573.0,
#   12.35,
#   13.87,
#   1302028.0),
#  (17, 'Bermudes', 2013, 2513, 'Orge', 'vegetal', 0.0, 0.0, None, 0.0),
#  (17, 'Bermudes', 2013, 2514, 'Maïs', 'vegetal', 25.0, 0.55, None, 68802.5),
#  (17,
#   'Bermudes',
#   2013,
#   2520,
#   'Céréales, Autres',
#   'vegetal',
#   4.0,
#   0.13,
#   0.0,
#   12337.0),
#  (17,
#   'Bermudes',
#   2013,
#   2531,
#   'Pommes de Terre',
#   'vegetal',
#   29.0,
#   0.72,
#   0.04,
#   380311.75000000006),
#  (17, 'Bermudes', 2013, 2532, 'Manioc', 'vegetal', 1.0, 0.0, None, 9490.0),
#  (17,
#   'Bermudes',
#   2013,
#   2533,
#   'Patates douces',
#   'vegetal',
#   6.0,
#   0.04,
#   None,
#   56465.5),
#  (17,
#   'Bermudes',
#   2013,
#   2534,
#   'Racines nda',
#   'vegetal',
#   1.0,
#   None,
#   None,
#   15184.0),
#  (17,
#   'Bermudes',
#   2013,
#   2542,
#   'Sucre Eq Brut',
#   'vegetal',
#   235.0,
#   None,
#   None,
#   544726.0),
#  (17,
#   'Bermudes',
#   2013,
#   2543,
#   'Edulcorants Autres',
#   'vegetal',
#   101.0,
#   None,
#   None,
#   478770.5),
#  (17,
#   'Bermudes',
#   2013,
#   2546,
#   'Haricots',
#   'vegetal',
#   13.0,
#   0.84,
#   None,
#   33215.0),
#  (17, 'Bermudes', 2013, 2547, 'Pois', 'vegetal', 5.0, 0.3, None, 11388.0),
#  (17,
#   'Bermudes',
#   2013,
#   2549,
#   'Légumineuses Autres',
#   'vegetal',
#   2.0,
#   0.17,
#   0.0,
#   5456.75),
#  (17, 'Bermudes', 2013, 2551, 'Noix', 'vegetal', 36.0, 1.05, 3.37, 110084.0),
#  (17, 'Bermudes', 2013, 2555, 'Soja', 'vegetal', 1.0, None, None, 5219.5),
#  (17,
#   'Bermudes',
#   2013,
#   2556,
#   'Arachides Decortiquees',
#   'vegetal',
#   17.0,
#   0.72,
#   1.48,
#   25623.0),
#  (17,
#   'Bermudes',
#   2013,
#   2557,
#   'Graines de tournesol',
#   'vegetal',
#   1.0,
#   None,
#   None,
#   4033.25),
#  (17,
#   'Bermudes',
#   2013,
#   2558,
#   'Graines Colza/Moutarde',
#   'vegetal',
#   9.0,
#   0.0,
#   1.0,
#   23725.0),
#  (17,
#   'Bermudes',
#   2013,
#   2560,
#   'Coco (Incl Coprah)',
#   'vegetal',
#   2.0,
#   None,
#   None,
#   12811.5),
#  (17, 'Bermudes', 2013, 2563, 'Olives', 'vegetal', 2.0, None, None, 15658.5),
#  (17,
#   'Bermudes',
#   2013,
#   2570,
#   'Plantes Oleiferes, Autre',
#   'vegetal',
#   5.0,
#   None,
#   None,
#   9964.5),
#  (17,
#   'Bermudes',
#   2013,
#   2572,
#   "Huile d'Arachide",
#   'vegetal',
#   1.0,
#   None,
#   None,
#   None),
#  (17,
#   'Bermudes',
#   2013,
#   2573,
#   'Huile de Tournesol',
#   'vegetal',
#   1.0,
#   None,
#   None,
#   None),
#  (17,
#   'Bermudes',
#   2013,
#   2574,
#   'Huile de Colza&Moutarde',
#   'vegetal',
#   53.0,
#   None,
#   6.07,
#   52669.5),
#  (17,
#   'Bermudes',
#   2013,
#   2577,
#   'Huile de Palme',
#   'vegetal',
#   0.0,
#   None,
#   0.0,
#   0.0),
#  (17,
#   'Bermudes',
#   2013,
#   2578,
#   'Huile de Coco',
#   'vegetal',
#   3.0,
#   None,
#   None,
#   None),
#  (17,
#   'Bermudes',
#   2013,
#   2579,
#   'Huile de Sésame',
#   'vegetal',
#   1.0,
#   None,
#   None,
#   None),
#  (17,
#   'Bermudes',
#   2013,
#   2580,
#   "Huile d'Olive",
#   'vegetal',
#   36.0,
#   None,
#   4.09,
#   35350.25),
#  (17,
#   'Bermudes',
#   2013,
#   2582,
#   'Huile de Germe de Maïs',
#   'vegetal',
#   17.0,
#   None,
#   1.94,
#   16844.75),
#  (17,
#   'Bermudes',
#   2013,
#   2586,
#   'Huil Plantes Oleif Autr',
#   'vegetal',
#   75.0,
#   0.04,
#   8.51,
#   74733.75),
#  (17,
#   'Bermudes',
#   2013,
#   2601,
#   'Tomates',
#   'vegetal',
#   13.0,
#   0.59,
#   None,
#   635355.5),
#  (17, 'Bermudes', 2013, 2602, 'Oignons', 'vegetal', 8.0, 0.3, None, 224438.5),
#  ...]

# %%
CREATE TABLE "dispo" (
"pays"	TEXT NOT NULL,
"code_pays"	INTEGER NOT NULL,
"année"	INTEGER NOT NULL,
"produit"	TEXT NOT NULL,
"code_produit"	INTEGER NOT NULL,
"dispo_int"	REAL,
"dispo_kcal"	REAL,
"dispo_kg"	REAL,
"pertes"	REAL,
"autres_utilisations"	REAL,
PRIMARY KEY("code_pays","code_produit")
);

# %%
CREATE TABLE "equilibre_prod" (
	"pays"	TEXT,
	"code_pays"	INTEGER NOT NULL,
	"année"	INTEGER NOT NULL,
	"produit"	TEXT NOT NULL,
	"code_produit"	INTEGER NOT NULL,
	"dispo_int"	REAL,
	"alim_ani"	REAL,
	"semences"	REAL,
	"pertes"	REAL,
	"transfo"	REAL,
	"nourriture"	REAL,
	"autres_utilisations"	REAL,
	PRIMARY KEY("code_pays","code_produit")
);

# %%
CREATE TABLE "sous_nutrition" (
	"pays"	TEXT NOT NULL,
	" code pays"	INTEGER NOT NULL,
	"nb_personnes"	REAL NOT NULL,
	"annee"	INTEGER NOT NULL,
	PRIMARY KEY(" code pays")
);

# %%
CREATE TABLE "dispo_alim" (
	"code_pays"	INTEGER NOT NULL,
	"pays"	TEXT,
	"année"	INTEGER NOT NULL,
	"code_produit"	INTEGER NOT NULL,
	"produit"	TEXT,
	"origin"	TEXT,
	"dispo_alim_kcal_p_j"	REAL,
	"dispo_prot"	REAL,
	"dispo_mat_gr"	REAL,
	"dispo_alim_tonnes"	REAL,
	PRIMARY KEY("code_pays","code_produit")
);
